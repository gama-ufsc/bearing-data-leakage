# %%
import pandas as pd
import numpy as np

import autorootcwd  # noqa
from hamilton import driver

from src.data import data_pipeline
from src.data.pydantic_models import BearingDataset
from functools import partial
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import (
    RandomizedSearchCV,
    GroupKFold,
    cross_validate,
    cross_val_predict,
)
from scipy.stats import randint, loguniform
import logging
import random
from src.utils.add_signal_data import add_signal_data_paderborn, add_signal_data_ottawa, add_signal_data_cwru

# %%
from src.data.data_splits import train_test_split_proposed
from itertools import combinations, product
import random

# %%
healthy_bearing_ids = ["K001", "K002", "K003", "K004", "K005", "K006"]
outer_bearing_ids = ["KA04", "KA15", "KA16", "KA22", "KA30"]
inner_bearing_ids = ["KI04", "KI14", "KI16", "KI18", "KI21", "KI17"]


class CombinationSampler:
    def __init__(self, list1, list2, list3, random_seed=42):
        self.combinations = list(product(list1, list2, list3))
        random.seed(random_seed)
        random.shuffle(self.combinations)

    def get_combination(self, run: int):
        if not self.combinations:
            raise ValueError("No more combinations available")
        combination = self.combinations[run]

        return combination


list1 = [
    ["K001", "K003"],
    ["K001", "K002"],
    ["K001", "K004"],
    ["K001", "K005"],
    ["K001", "K006"],
    ["K002", "K003"],
    ["K002", "K004"],
    ["K002", "K005"],
    ["K002", "K006"],
    ["K003", "K004"],
    ["K003", "K005"],
    ["K003", "K006"],
    ["K004", "K005"],
    ["K004", "K006"],
    ["K005", "K006"],
]

list2 = [
    ["KA04", "KA16"],
    ["KA04", "KA15"],
    ["KA04", "KA22"],
    ["KA04", "KA30"],
    ["KA15", "KA16"],
    ["KA15", "KA22"],
    ["KA15", "KA30"],
    ["KA16", "KA22"],
    ["KA16", "KA30"],
    ["KA22", "KA30"],
]

list3 = [
    ["KI04", "KI16"],
    ["KI04", "KI14"],
    ["KI04", "KI21"],
    ["KI04", "KI18"],
    ["KI04", "KI17"],
    ["KI14", "KI16"],
    ["KI14", "KI18"],
    ["KI14", "KI21"],
    ["KI14", "KI17"],
    ["KI16", "KI18"],
    ["KI16", "KI21"],
    ["KI16", "KI17"],
    ["KI18", "KI21"],
    ["KI18", "KI17"],
    ["KI21", "KI17"],
]

sampler = CombinationSampler(list1, list2, list3)

def get_cv_splits(
    df: pd.DataFrame,
    sampler: CombinationSampler,
    run: int,
    healthy_bearing_ids: list,
    outer_bearing_ids: list,
    inner_bearing_ids: list,
    use_combined: bool = False,
    on_train: bool = False,
):

    combination = sampler.get_combination(run=run)

    train_ids = (
        list(set(healthy_bearing_ids).difference(set(combination[0])))
        + list(set(outer_bearing_ids).difference(set(combination[1])))
        + list(set(inner_bearing_ids).difference(set(combination[2])))
    )

    test_ids = list(combination[0] + combination[1] + combination[2])

    if use_combined:
        combined_bearings_ids = ["KB23", "KB24", "KB27"]
        if on_train:
            print(f"Using combined bearings on train: {combined_bearings_ids}")
            train_ids += combined_bearings_ids
        else:
            print(f"Using combined bearings on test: {combined_bearings_ids}")
            test_ids += combined_bearings_ids

    train_idx = df[df["bearing_id"].isin(train_ids)].index.values
    test_idx = df[df["bearing_id"].isin(test_ids)].index.values

    cv = (train_idx, test_idx)

    return cv

# %%
metadata = pd.read_pickle("/data/bearing_datasets/paderborn/processed/files_metadata.bz2")
features = pd.read_pickle("/home/joao-paulo-vieira/mestrado/leakage_paper_experiments/data/features/pd_features.pkl")

# %%
df = features.merge(metadata, on="waveform_id", how="left")

# %%
cvs = [get_cv_splits(sampler=sampler, df=df, run=run,
 healthy_bearing_ids=healthy_bearing_ids, outer_bearing_ids=outer_bearing_ids,
  inner_bearing_ids=inner_bearing_ids, use_combined=False, on_train=False)
 for run in range(5)]

# %%
features = ['acceleration/rms/global', 'acceleration/pk-pk/global',
       'acceleration/kurt/global', 'acceleration/skewness/global',
       'acceleration/fc/global', 'acceleration/shape_factor/global',
       'acceleration/impulse_factor/global',
       'acceleration/clearance_factor/global', 'acceleration/fcPlus/global',
       'envelope/spectralPeak/1.0x-bpfo/50-1000',
       'envelope/spectralPeak/2.0x-bpfo/50-1000',
       'envelope/spectralPeak/3.0x-bpfo/50-1000',
       'envelope/spectralPeak/4.0x-bpfo/50-1000',
       'envelope/spectralPeak/5.0x-bpfo/50-1000',
       'envelope/spectralPeak/1.0x-bpfi/50-1000',
       'envelope/spectralPeak/2.0x-bpfi/50-1000',
       'envelope/spectralPeak/3.0x-bpfi/50-1000',
       'envelope/spectralPeak/4.0x-bpfi/50-1000',
       'envelope/spectralPeak/5.0x-bpfi/50-1000',
       'envelope/spectralPeak/1.0x-bpfo/50-5000',
       'envelope/spectralPeak/2.0x-bpfo/50-5000',
       'envelope/spectralPeak/3.0x-bpfo/50-5000',
       'envelope/spectralPeak/4.0x-bpfo/50-5000',
       'envelope/spectralPeak/5.0x-bpfo/50-5000',
       'envelope/spectralPeak/1.0x-bpfi/50-5000',
       'envelope/spectralPeak/2.0x-bpfi/50-5000',
       'envelope/spectralPeak/3.0x-bpfi/50-5000',
       'envelope/spectralPeak/4.0x-bpfi/50-5000',
       'envelope/spectralPeak/5.0x-bpfi/50-5000',
       'envelope/spectralPeak/1.0x-bpfo/500-10000',
       'envelope/spectralPeak/2.0x-bpfo/500-10000',
       'envelope/spectralPeak/3.0x-bpfo/500-10000',
       'envelope/spectralPeak/4.0x-bpfo/500-10000',
       'envelope/spectralPeak/5.0x-bpfo/500-10000',
       'envelope/spectralPeak/1.0x-bpfi/500-10000',
       'envelope/spectralPeak/2.0x-bpfi/500-10000',
       'envelope/spectralPeak/3.0x-bpfi/500-10000',
       'envelope/spectralPeak/4.0x-bpfi/500-10000',
       'envelope/spectralPeak/5.0x-bpfi/500-10000',
       'envelope/spectralPeak/1.0x-bsf/500-10000',]

# %%
X = df[features].copy()
y = df[['inner', 'outer']].copy()

# %% [markdown]
# # Features (segmented)

# %% [markdown]
# ## RF

# %%
random_search = RandomizedSearchCV(
    estimator=MultiOutputClassifier(RandomForestClassifier()),
    param_distributions={
        "estimator__n_estimators": [200],
        "estimator__max_features": ["sqrt", "log2"],
        "estimator__criterion": ["gini", "entropy", "log_loss"],
        "estimator__max_depth": randint(low=2, high=60),
        "estimator__min_samples_split": randint(low=2, high=20),
        "estimator__min_samples_leaf": randint(low=1, high=20),
        "estimator__ccp_alpha": loguniform(1e-5, 1),
    },
    n_iter=250,
    cv=cvs,
    scoring="roc_auc",
    verbose=2,
    n_jobs=-1,
)

random_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 250 candidates, totalling 1250 fits
# [CV] END estimator__ccp_alpha=0.0013140714793113144, estimator__criterion=log_loss, estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=14, estimator__n_estimators=200; total time=   1.7s
# [CV] END estimator__ccp_alpha=0.0013140714793113144, estimator__criterion=log_loss, estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=14, estimator__n_estimators=200; total time=   1.8s
# [CV] END estimator__ccp_alpha=0.0013140714793113144, estimator__criterion=log_loss, estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=14, estimator__n_estimators=200; total time=   2.0s
# [CV] END estimator__ccp_alpha=0.0013140714793113144, estimator__criterion=log_loss, estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=14, estimator__n_estimators=200; total time=   2.1s
# [CV] END estimator__ccp_alpha=0.0012557167550063715, estimator__criterion=gini, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   4.3s
# [CV] END estimator__ccp_alpha=0.0012557167550063715, estimator__criterion=gini, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   5.6s
# [CV] END estimator__ccp_alpha=0.002095074644917865, estimator__criterion=log_loss, estimator__max_depth=19, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   5.7s
# [CV] END estimator__ccp_alpha=0.0012557167550063715, estimator__criterion=gini, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   5.8s
# [CV] END estimator__ccp_alpha=0.014617599069590575, estimator__criterion=log_loss, estimator__max_depth=48, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=0.0012557167550063715, estimator__criterion=gini, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   5.8s
# [CV] END estimator__ccp_alpha=0.0012557167550063715, estimator__criterion=gini, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   6.0s
# [CV] END estimator__ccp_alpha=0.0013140714793113144, estimator__criterion=log_loss, estimator__max_depth=2, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=14, estimator__n_estimators=200; total time=   4.1s
# [CV] END estimator__ccp_alpha=0.002095074644917865, estimator__criterion=log_loss, estimator__max_depth=19, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   6.2s
# [CV] END estimator__ccp_alpha=0.014617599069590575, estimator__criterion=log_loss, estimator__max_depth=48, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   6.4s
# [CV] END estimator__ccp_alpha=0.014617599069590575, estimator__criterion=log_loss, estimator__max_depth=48, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   6.5s
# [CV] END estimator__ccp_alpha=5.947079188036131e-05, estimator__criterion=entropy, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=6, estimator__n_estimators=200; total time=   6.6s
# [CV] END estimator__ccp_alpha=5.947079188036131e-05, estimator__criterion=entropy, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=6, estimator__n_estimators=200; total time=   6.6s
# [CV] END estimator__ccp_alpha=0.014617599069590575, estimator__criterion=log_loss, estimator__max_depth=48, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   6.5s
# [CV] END estimator__ccp_alpha=0.002095074644917865, estimator__criterion=log_loss, estimator__max_depth=19, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   6.6s
# [CV] END estimator__ccp_alpha=0.014617599069590575, estimator__criterion=log_loss, estimator__max_depth=48, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   6.7s
# [CV] END estimator__ccp_alpha=0.002095074644917865, estimator__criterion=log_loss, estimator__max_depth=19, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   6.7s
# [CV] END estimator__ccp_alpha=0.002095074644917865, estimator__criterion=log_loss, estimator__max_depth=19, estimator__max_features=log2, estimator__min_samples_leaf=5, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   7.0s
# [CV] END estimator__ccp_alpha=5.947079188036131e-05, estimator__criterion=entropy, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=6, estimator__n_estimators=200; total time=   7.2s
# [CV] END estimator__ccp_alpha=5.947079188036131e-05, estimator__criterion=entropy, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=6, estimator__n_estimators=200; total time=   7.3s
# [CV] END estimator__ccp_alpha=5.947079188036131e-05, estimator__criterion=entropy, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=6, estimator__n_estimators=200; total time=   7.4s
# [CV] END estimator__ccp_alpha=0.0001347176028933554, estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=log2, estimator__min_samples_leaf=19, estimator__min_samples_split=13, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=0.0001347176028933554, estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=log2, estimator__min_samples_leaf=19, estimator__min_samples_split=13, estimator__n_estimators=200; total time=   6.6s
# [CV] END estimator__ccp_alpha=0.0001347176028933554, estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=log2, estimator__min_samples_leaf=19, estimator__min_samples_split=13, estimator__n_estimators=200; total time=   6.1s
# [CV] END estimator__ccp_alpha=0.0001347176028933554, estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=log2, estimator__min_samples_leaf=19, estimator__min_samples_split=13, estimator__n_estimators=200; total time=   4.3s
# [CV] END estimator__ccp_alpha=4.244425377676328e-05, estimator__criterion=log_loss, estimator__max_depth=25, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=17, estimator__n_estimators=200; total time=   3.4s
# [CV] END estimator__ccp_alpha=4.244425377676328e-05, estimator__criterion=log_loss, estimator__max_depth=25, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=17, estimator__n_estimators=200; total time=   3.7s
# [CV] END estimator__ccp_alpha=0.0016112730945633611, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=10, estimator__min_samples_split=18, estimator__n_estimators=200; total time=   3.0s
# [CV] END estimator__ccp_alpha=0.0075783583014988306, estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   3.7s
# [CV] END estimator__ccp_alpha=0.0016112730945633611, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=10, estimator__min_samples_split=18, estimator__n_estimators=200; total time=   3.2s
# [CV] END estimator__ccp_alpha=0.0001347176028933554, estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=log2, estimator__min_samples_leaf=19, estimator__min_samples_split=13, estimator__n_estimators=200; total time=   4.2s
# [CV] END estimator__ccp_alpha=4.244425377676328e-05, estimator__criterion=log_loss, estimator__max_depth=25, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=17, estimator__n_estimators=200; total time=   4.0s
# [CV] END estimator__ccp_alpha=0.0016112730945633611, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=10, estimator__min_samples_split=18, estimator__n_estimators=200; total time=   3.5s
# [CV] END estimator__ccp_alpha=0.0016112730945633611, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=10, estimator__min_samples_split=18, estimator__n_estimators=200; total time=   3.3s
# [CV] END estimator__ccp_alpha=4.244425377676328e-05, estimator__criterion=log_loss, estimator__max_depth=25, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=17, estimator__n_estimators=200; total time=   4.3s
# [CV] END estimator__ccp_alpha=0.0075783583014988306, estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   4.2s
# [CV] END estimator__ccp_alpha=4.244425377676328e-05, estimator__criterion=log_loss, estimator__max_depth=25, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=17, estimator__n_estimators=200; total time=   4.6s
# [CV] END estimator__ccp_alpha=0.0075783583014988306, estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   4.0s
# [CV] END estimator__ccp_alpha=0.0075783583014988306, estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   4.3s
# [CV] END estimator__ccp_alpha=0.0016112730945633611, estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__min_samples_leaf=10, estimator__min_samples_split=18, estimator__n_estimators=200; total time=   4.3s
# [CV] END estimator__ccp_alpha=0.0075783583014988306, estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   4.6s
# [CV] END estimator__ccp_alpha=0.10081391858255535, estimator__criterion=entropy, estimator__max_depth=45, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   4.4s
# [CV] END estimator__ccp_alpha=0.10081391858255535, estimator__criterion=entropy, estimator__max_depth=45, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   5.1s
# [CV] END estimator__ccp_alpha=0.10081391858255535, estimator__criterion=entropy, estimator__max_depth=45, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   4.9s
# [CV] END estimator__ccp_alpha=0.10081391858255535, estimator__criterion=entropy, estimator__max_depth=45, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   5.3s
# [CV] END estimator__ccp_alpha=0.003268691824843272, estimator__criterion=gini, estimator__max_depth=46, estimator__max_features=log2, estimator__min_samples_leaf=15, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   4.2s
# [CV] END estimator__ccp_alpha=0.003268691824843272, estimator__criterion=gini, estimator__max_depth=46, estimator__max_features=log2, estimator__min_samples_leaf=15, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   3.9s
# [CV] END estimator__ccp_alpha=0.003268691824843272, estimator__criterion=gini, estimator__max_depth=46, estimator__max_features=log2, estimator__min_samples_leaf=15, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   4.4s
# [CV] END estimator__ccp_alpha=0.10081391858255535, estimator__criterion=entropy, estimator__max_depth=45, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   4.9s
# [CV] END estimator__ccp_alpha=0.003268691824843272, estimator__criterion=gini, estimator__max_depth=46, estimator__max_features=log2, estimator__min_samples_leaf=15, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   3.8s
# [CV] END estimator__ccp_alpha=0.003268691824843272, estimator__criterion=gini, estimator__max_depth=46, estimator__max_features=log2, estimator__min_samples_leaf=15, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   4.1s
# [CV] END estimator__ccp_alpha=0.8428528812667091, estimator__criterion=gini, estimator__max_depth=41, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   4.4s
# [CV] END estimator__ccp_alpha=0.8428528812667091, estimator__criterion=gini, estimator__max_depth=41, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   4.6s
# [CV] END estimator__ccp_alpha=0.8428528812667091, estimator__criterion=gini, estimator__max_depth=41, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   4.7s
# [CV] END estimator__ccp_alpha=0.8428528812667091, estimator__criterion=gini, estimator__max_depth=41, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.8428528812667091, estimator__criterion=gini, estimator__max_depth=41, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   4.5s
# [CV] END estimator__ccp_alpha=0.3380894568725416, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=11, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   5.2s
# [CV] END estimator__ccp_alpha=0.3380894568725416, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=11, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   5.3s
# [CV] END estimator__ccp_alpha=0.3380894568725416, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=11, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   5.4s
# [CV] END estimator__ccp_alpha=0.3380894568725416, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=11, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   5.5s
# [CV] END estimator__ccp_alpha=0.022809539117521635, estimator__criterion=gini, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   4.9s
# [CV] END estimator__ccp_alpha=0.022809539117521635, estimator__criterion=gini, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   4.3s
# [CV] END estimator__ccp_alpha=0.022809539117521635, estimator__criterion=gini, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   4.4s
# [CV] END estimator__ccp_alpha=0.3380894568725416, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=11, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   5.8s
# [CV] END estimator__ccp_alpha=0.022809539117521635, estimator__criterion=gini, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.022809539117521635, estimator__criterion=gini, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   4.6s
# [CV] END estimator__ccp_alpha=0.42439141190464263, estimator__criterion=log_loss, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=13, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.42439141190464263, estimator__criterion=log_loss, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=13, estimator__n_estimators=200; total time=   4.4s
# [CV] END estimator__ccp_alpha=0.42439141190464263, estimator__criterion=log_loss, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=13, estimator__n_estimators=200; total time=   5.0s
# [CV] END estimator__ccp_alpha=0.42439141190464263, estimator__criterion=log_loss, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=13, estimator__n_estimators=200; total time=   5.2s
# [CV] END estimator__ccp_alpha=0.42439141190464263, estimator__criterion=log_loss, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=13, estimator__n_estimators=200; total time=   5.2s
# [CV] END estimator__ccp_alpha=0.0009769101109265825, estimator__criterion=log_loss, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   5.4s
# [CV] END estimator__ccp_alpha=0.0009769101109265825, estimator__criterion=log_loss, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=0.0009769101109265825, estimator__criterion=log_loss, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   6.3s
# [CV] END estimator__ccp_alpha=0.0009769101109265825, estimator__criterion=log_loss, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=0.0009769101109265825, estimator__criterion=log_loss, estimator__max_depth=7, estimator__max_features=log2, estimator__min_samples_leaf=12, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   6.4s
# [CV] END estimator__ccp_alpha=0.539779790296155, estimator__criterion=log_loss, estimator__max_depth=33, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=15, estimator__n_estimators=200; total time=   6.1s
# [CV] END estimator__ccp_alpha=2.550866295602588e-05, estimator__criterion=log_loss, estimator__max_depth=21, estimator__max_features=log2, estimator__min_samples_leaf=14, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=0.8126880874788872, estimator__criterion=log_loss, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.7s
# [CV] END estimator__ccp_alpha=2.550866295602588e-05, estimator__criterion=log_loss, estimator__max_depth=21, estimator__max_features=log2, estimator__min_samples_leaf=14, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   6.1s
# [CV] END estimator__ccp_alpha=0.8126880874788872, estimator__criterion=log_loss, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.2s
# [CV] END estimator__ccp_alpha=2.550866295602588e-05, estimator__criterion=log_loss, estimator__max_depth=21, estimator__max_features=log2, estimator__min_samples_leaf=14, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   6.3s
# [CV] END estimator__ccp_alpha=0.539779790296155, estimator__criterion=log_loss, estimator__max_depth=33, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=15, estimator__n_estimators=200; total time=   7.0s
# [CV] END estimator__ccp_alpha=0.539779790296155, estimator__criterion=log_loss, estimator__max_depth=33, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=15, estimator__n_estimators=200; total time=   6.9s
# [CV] END estimator__ccp_alpha=0.8126880874788872, estimator__criterion=log_loss, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   6.4s
# [CV] END estimator__ccp_alpha=2.550866295602588e-05, estimator__criterion=log_loss, estimator__max_depth=21, estimator__max_features=log2, estimator__min_samples_leaf=14, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   6.7s
# [CV] END estimator__ccp_alpha=2.550866295602588e-05, estimator__criterion=log_loss, estimator__max_depth=21, estimator__max_features=log2, estimator__min_samples_leaf=14, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   6.7s
# [CV] END estimator__ccp_alpha=0.539779790296155, estimator__criterion=log_loss, estimator__max_depth=33, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=15, estimator__n_estimators=200; total time=   6.8s
# [CV] END estimator__ccp_alpha=0.8126880874788872, estimator__criterion=log_loss, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   6.5s
# [CV] END estimator__ccp_alpha=0.539779790296155, estimator__criterion=log_loss, estimator__max_depth=33, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=15, estimator__n_estimators=200; total time=   7.5s
# [CV] END estimator__ccp_alpha=0.8126880874788872, estimator__criterion=log_loss, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=17, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.6s
# [CV] END estimator__ccp_alpha=0.0005374836123652606, estimator__criterion=entropy, estimator__max_depth=13, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   5.2s
# [CV] END estimator__ccp_alpha=0.0005374836123652606, estimator__criterion=entropy, estimator__max_depth=13, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   4.9s
# [CV] END estimator__ccp_alpha=0.0005374836123652606, estimator__criterion=entropy, estimator__max_depth=13, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   5.6s
# [CV] END estimator__ccp_alpha=0.00044029952905452416, estimator__criterion=entropy, estimator__max_depth=41, estimator__max_features=log2, estimator__min_samples_leaf=18, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   4.3s
# [CV] END estimator__ccp_alpha=0.0005374836123652606, estimator__criterion=entropy, estimator__max_depth=13, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   6.2s
# [CV] END estimator__ccp_alpha=0.0005374836123652606, estimator__criterion=entropy, estimator__max_depth=13, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   5.1s
# [CV] END estimator__ccp_alpha=0.00044029952905452416, estimator__criterion=entropy, estimator__max_depth=41, estimator__max_features=log2, estimator__min_samples_leaf=18, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   4.3s
# [CV] END estimator__ccp_alpha=0.00044029952905452416, estimator__criterion=entropy, estimator__max_depth=41, estimator__max_features=log2, estimator__min_samples_leaf=18, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   4.6s
# [CV] END estimator__ccp_alpha=0.00044029952905452416, estimator__criterion=entropy, estimator__max_depth=41, estimator__max_features=log2, estimator__min_samples_leaf=18, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   4.6s
# [CV] END estimator__ccp_alpha=0.00044029952905452416, estimator__criterion=entropy, estimator__max_depth=41, estimator__max_features=log2, estimator__min_samples_leaf=18, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.00039340827817123386, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=19, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.00039340827817123386, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=19, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   5.3s
# [CV] END estimator__ccp_alpha=0.00039340827817123386, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=19, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   5.5s
# [CV] END estimator__ccp_alpha=0.00039340827817123386, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=19, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   5.6s
# [CV] END estimator__ccp_alpha=0.03070762140293772, estimator__criterion=log_loss, estimator__max_depth=19, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.1s
# [CV] END estimator__ccp_alpha=0.00039340827817123386, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=19, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   5.6s
# [CV] END estimator__ccp_alpha=0.03070762140293772, estimator__criterion=log_loss, estimator__max_depth=19, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.3s
# [CV] END estimator__ccp_alpha=0.0582229531287423, estimator__criterion=entropy, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   5.4s
# [CV] END estimator__ccp_alpha=0.0582229531287423, estimator__criterion=entropy, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   5.6s
# [CV] END estimator__ccp_alpha=0.03070762140293772, estimator__criterion=log_loss, estimator__max_depth=19, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.2s
# [CV] END estimator__ccp_alpha=0.03070762140293772, estimator__criterion=log_loss, estimator__max_depth=19, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.1s
# [CV] END estimator__ccp_alpha=0.04512637963953776, estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=sqrt, estimator__min_samples_leaf=15, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   4.2s
# [CV] END estimator__ccp_alpha=0.03070762140293772, estimator__criterion=log_loss, estimator__max_depth=19, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.1s
# [CV] END estimator__ccp_alpha=0.0582229531287423, estimator__criterion=entropy, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=0.04512637963953776, estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=sqrt, estimator__min_samples_leaf=15, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   4.9s
# [CV] END estimator__ccp_alpha=0.04512637963953776, estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=sqrt, estimator__min_samples_leaf=15, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   4.5s
# [CV] END estimator__ccp_alpha=0.04512637963953776, estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=sqrt, estimator__min_samples_leaf=15, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.0582229531287423, estimator__criterion=entropy, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   6.0s
# [CV] END estimator__ccp_alpha=0.0582229531287423, estimator__criterion=entropy, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   6.0s
# [CV] END estimator__ccp_alpha=0.04512637963953776, estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=sqrt, estimator__min_samples_leaf=15, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   5.0s
# [CV] END estimator__ccp_alpha=0.00011467426382990278, estimator__criterion=log_loss, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.00011467426382990278, estimator__criterion=log_loss, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   5.4s
# [CV] END estimator__ccp_alpha=0.00011467426382990278, estimator__criterion=log_loss, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   3.7s
# [CV] END estimator__ccp_alpha=0.00011467426382990278, estimator__criterion=log_loss, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   4.1s
# [CV] END estimator__ccp_alpha=0.00011467426382990278, estimator__criterion=log_loss, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   5.7s
# [CV] END estimator__ccp_alpha=1.76638887958795e-05, estimator__criterion=gini, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   5.5s
# [CV] END estimator__ccp_alpha=0.0019752919024338387, estimator__criterion=entropy, estimator__max_depth=54, estimator__max_features=sqrt, estimator__min_samples_leaf=15, estimator__min_samples_split=19, estimator__n_estimators=200; total time=   6.1s
# [CV] END estimator__ccp_alpha=0.0019752919024338387, estimator__criterion=entropy, estimator__max_depth=54, estimator__max_features=sqrt, estimator__min_samples_leaf=15, estimator__min_samples_split=19, estimator__n_estimators=200; total time=   6.6s
# [CV] END estimator__ccp_alpha=0.0019752919024338387, estimator__criterion=entropy, estimator__max_depth=54, estimator__max_features=sqrt, estimator__min_samples_leaf=15, estimator__min_samples_split=19, estimator__n_estimators=200; total time=   6.6s
# [CV] END estimator__ccp_alpha=1.76638887958795e-05, estimator__criterion=gini, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   5.6s
# [CV] END estimator__ccp_alpha=1.76638887958795e-05, estimator__criterion=gini, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   5.8s
# [CV] END estimator__ccp_alpha=1.76638887958795e-05, estimator__criterion=gini, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   6.1s
# [CV] END estimator__ccp_alpha=0.012817599753876112, estimator__criterion=gini, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=11, estimator__min_samples_split=15, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=1.76638887958795e-05, estimator__criterion=gini, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   6.0s
# [CV] END estimator__ccp_alpha=0.012817599753876112, estimator__criterion=gini, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=11, estimator__min_samples_split=15, estimator__n_estimators=200; total time=   5.5s
# [CV] END estimator__ccp_alpha=0.00011429043375679816, estimator__criterion=entropy, estimator__max_depth=55, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   6.3s
# [CV] END estimator__ccp_alpha=0.0019752919024338387, estimator__criterion=entropy, estimator__max_depth=54, estimator__max_features=sqrt, estimator__min_samples_leaf=15, estimator__min_samples_split=19, estimator__n_estimators=200; total time=   6.9s
# [CV] END estimator__ccp_alpha=0.012817599753876112, estimator__criterion=gini, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=11, estimator__min_samples_split=15, estimator__n_estimators=200; total time=   6.0s
# [CV] END estimator__ccp_alpha=0.0019752919024338387, estimator__criterion=entropy, estimator__max_depth=54, estimator__max_features=sqrt, estimator__min_samples_leaf=15, estimator__min_samples_split=19, estimator__n_estimators=200; total time=   6.8s
# [CV] END estimator__ccp_alpha=0.012817599753876112, estimator__criterion=gini, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=11, estimator__min_samples_split=15, estimator__n_estimators=200; total time=   6.3s
# [CV] END estimator__ccp_alpha=0.00011429043375679816, estimator__criterion=entropy, estimator__max_depth=55, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   6.8s
# [CV] END estimator__ccp_alpha=0.00011429043375679816, estimator__criterion=entropy, estimator__max_depth=55, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   7.2s
# [CV] END estimator__ccp_alpha=0.00011429043375679816, estimator__criterion=entropy, estimator__max_depth=55, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   7.3s
# [CV] END estimator__ccp_alpha=0.00011429043375679816, estimator__criterion=entropy, estimator__max_depth=55, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=9, estimator__n_estimators=200; total time=   7.4s
# [CV] END estimator__ccp_alpha=0.012817599753876112, estimator__criterion=gini, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=11, estimator__min_samples_split=15, estimator__n_estimators=200; total time=   6.3s
# [CV] END estimator__ccp_alpha=0.046522298067323435, estimator__criterion=entropy, estimator__max_depth=35, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   6.6s
# [CV] END estimator__ccp_alpha=0.046522298067323435, estimator__criterion=entropy, estimator__max_depth=35, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=0.046522298067323435, estimator__criterion=entropy, estimator__max_depth=35, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   6.6s
# [CV] END estimator__ccp_alpha=0.046522298067323435, estimator__criterion=entropy, estimator__max_depth=35, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   4.6s
# [CV] END estimator__ccp_alpha=0.1295893183733113, estimator__criterion=gini, estimator__max_depth=21, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   3.3s
# [CV] END estimator__ccp_alpha=0.000120097029966177, estimator__criterion=entropy, estimator__max_depth=11, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   3.9s
# [CV] END estimator__ccp_alpha=0.1295893183733113, estimator__criterion=gini, estimator__max_depth=21, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   4.7s
# [CV] END estimator__ccp_alpha=0.046522298067323435, estimator__criterion=entropy, estimator__max_depth=35, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   5.2s
# [CV] END estimator__ccp_alpha=0.000120097029966177, estimator__criterion=entropy, estimator__max_depth=11, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   5.2s
# [CV] END estimator__ccp_alpha=0.000120097029966177, estimator__criterion=entropy, estimator__max_depth=11, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   5.3s
# [CV] END estimator__ccp_alpha=0.000120097029966177, estimator__criterion=entropy, estimator__max_depth=11, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   5.1s
# [CV] END estimator__ccp_alpha=0.1295893183733113, estimator__criterion=gini, estimator__max_depth=21, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   5.1s
# [CV] END estimator__ccp_alpha=0.1295893183733113, estimator__criterion=gini, estimator__max_depth=21, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   5.0s
# [CV] END estimator__ccp_alpha=0.0028114726396967216, estimator__criterion=log_loss, estimator__max_depth=37, estimator__max_features=sqrt, estimator__min_samples_leaf=12, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   5.0s
# [CV] END estimator__ccp_alpha=0.000120097029966177, estimator__criterion=entropy, estimator__max_depth=11, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=0.1295893183733113, estimator__criterion=gini, estimator__max_depth=21, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   5.5s
# [CV] END estimator__ccp_alpha=0.0028114726396967216, estimator__criterion=log_loss, estimator__max_depth=37, estimator__max_features=sqrt, estimator__min_samples_leaf=12, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   5.2s
# [CV] END estimator__ccp_alpha=0.0028114726396967216, estimator__criterion=log_loss, estimator__max_depth=37, estimator__max_features=sqrt, estimator__min_samples_leaf=12, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   5.6s
# [CV] END estimator__ccp_alpha=0.0006381398446070238, estimator__criterion=entropy, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=6, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.0028114726396967216, estimator__criterion=log_loss, estimator__max_depth=37, estimator__max_features=sqrt, estimator__min_samples_leaf=12, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   5.8s
# [CV] END estimator__ccp_alpha=0.0006381398446070238, estimator__criterion=entropy, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=6, estimator__n_estimators=200; total time=   4.6s
# [CV] END estimator__ccp_alpha=0.0006381398446070238, estimator__criterion=entropy, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=6, estimator__n_estimators=200; total time=   5.4s
# [CV] END estimator__ccp_alpha=0.0006381398446070238, estimator__criterion=entropy, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=6, estimator__n_estimators=200; total time=   5.4s
# [CV] END estimator__ccp_alpha=0.0028114726396967216, estimator__criterion=log_loss, estimator__max_depth=37, estimator__max_features=sqrt, estimator__min_samples_leaf=12, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   6.0s
# [CV] END estimator__ccp_alpha=0.00022917676023437376, estimator__criterion=gini, estimator__max_depth=52, estimator__max_features=sqrt, estimator__min_samples_leaf=16, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.0006381398446070238, estimator__criterion=entropy, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=3, estimator__min_samples_split=6, estimator__n_estimators=200; total time=   5.0s
# [CV] END estimator__ccp_alpha=0.00022917676023437376, estimator__criterion=gini, estimator__max_depth=52, estimator__max_features=sqrt, estimator__min_samples_leaf=16, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   4.9s
# [CV] END estimator__ccp_alpha=0.00022917676023437376, estimator__criterion=gini, estimator__max_depth=52, estimator__max_features=sqrt, estimator__min_samples_leaf=16, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   4.2s
# [CV] END estimator__ccp_alpha=0.00022917676023437376, estimator__criterion=gini, estimator__max_depth=52, estimator__max_features=sqrt, estimator__min_samples_leaf=16, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   4.7s
# [CV] END estimator__ccp_alpha=0.00022917676023437376, estimator__criterion=gini, estimator__max_depth=52, estimator__max_features=sqrt, estimator__min_samples_leaf=16, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   4.5s
# [CV] END estimator__ccp_alpha=0.0015192185983783958, estimator__criterion=log_loss, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=7, estimator__min_samples_split=19, estimator__n_estimators=200; total time=   4.1s
# [CV] END estimator__ccp_alpha=0.0015192185983783958, estimator__criterion=log_loss, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=7, estimator__min_samples_split=19, estimator__n_estimators=200; total time=   5.6s
# [CV] END estimator__ccp_alpha=0.0027323800576786665, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   5.4s
# [CV] END estimator__ccp_alpha=0.0015192185983783958, estimator__criterion=log_loss, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=7, estimator__min_samples_split=19, estimator__n_estimators=200; total time=   6.3s
# [CV] END estimator__ccp_alpha=0.0027323800576786665, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   5.8s
# [CV] END estimator__ccp_alpha=0.0015192185983783958, estimator__criterion=log_loss, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=7, estimator__min_samples_split=19, estimator__n_estimators=200; total time=   6.3s
# [CV] END estimator__ccp_alpha=0.085332326225715, estimator__criterion=log_loss, estimator__max_depth=55, estimator__max_features=sqrt, estimator__min_samples_leaf=18, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   5.5s
# [CV] END estimator__ccp_alpha=0.0027323800576786665, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   6.6s
# [CV] END estimator__ccp_alpha=0.0015192185983783958, estimator__criterion=log_loss, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=7, estimator__min_samples_split=19, estimator__n_estimators=200; total time=   7.0s
# [CV] END estimator__ccp_alpha=0.085332326225715, estimator__criterion=log_loss, estimator__max_depth=55, estimator__max_features=sqrt, estimator__min_samples_leaf=18, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   6.1s
# [CV] END estimator__ccp_alpha=0.0027323800576786665, estimator__criterion=log_loss, estimator__max_depth=11, estimator__max_features=sqrt, estimator__min_samples_leaf=14, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   7.1s
# [CV] END estimator__ccp_alpha=0.085332326225715, estimator__criterion=log_loss, estimator__max_depth=55, estimator__max_features=sqrt, estimator__min_samples_leaf=18, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   7.0s
# ...
# [CV] END estimator__ccp_alpha=6.77965803184688e-05, estimator__criterion=log_loss, estimator__max_depth=23, estimator__max_features=sqrt, estimator__min_samples_leaf=16, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.8s
# [CV] END estimator__ccp_alpha=6.77965803184688e-05, estimator__criterion=log_loss, estimator__max_depth=23, estimator__max_features=sqrt, estimator__min_samples_leaf=16, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.3s
# [CV] END estimator__ccp_alpha=0.05608521215565299, estimator__criterion=gini, estimator__max_depth=57, estimator__max_features=sqrt, estimator__min_samples_leaf=7, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   4.5s
# [CV] END estimator__ccp_alpha=6.77965803184688e-05, estimator__criterion=log_loss, estimator__max_depth=23, estimator__max_features=sqrt, estimator__min_samples_leaf=16, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   4.9s
# [CV] END estimator__ccp_alpha=0.05608521215565299, estimator__criterion=gini, estimator__max_depth=57, estimator__max_features=sqrt, estimator__min_samples_leaf=7, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.5712315606400363, estimator__criterion=log_loss, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   4.3s
# [CV] END estimator__ccp_alpha=0.05608521215565299, estimator__criterion=gini, estimator__max_depth=57, estimator__max_features=sqrt, estimator__min_samples_leaf=7, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.05608521215565299, estimator__criterion=gini, estimator__max_depth=57, estimator__max_features=sqrt, estimator__min_samples_leaf=7, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   4.9s
# [CV] END estimator__ccp_alpha=0.05608521215565299, estimator__criterion=gini, estimator__max_depth=57, estimator__max_features=sqrt, estimator__min_samples_leaf=7, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.1s
# [CV] END estimator__ccp_alpha=0.5712315606400363, estimator__criterion=log_loss, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   4.9s
# [CV] END estimator__ccp_alpha=0.5712315606400363, estimator__criterion=log_loss, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   4.7s
# [CV] END estimator__ccp_alpha=0.5712315606400363, estimator__criterion=log_loss, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   4.6s
# [CV] END estimator__ccp_alpha=6.77965803184688e-05, estimator__criterion=log_loss, estimator__max_depth=23, estimator__max_features=sqrt, estimator__min_samples_leaf=16, estimator__min_samples_split=12, estimator__n_estimators=200; total time=   5.4s
# [CV] END estimator__ccp_alpha=0.5712315606400363, estimator__criterion=log_loss, estimator__max_depth=6, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   5.0s
# [CV] END estimator__ccp_alpha=0.03800123615200182, estimator__criterion=entropy, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=13, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.02054791711545146, estimator__criterion=gini, estimator__max_depth=11, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   4.3s
# [CV] END estimator__ccp_alpha=0.03800123615200182, estimator__criterion=entropy, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=13, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   4.4s
# [CV] END estimator__ccp_alpha=0.02054791711545146, estimator__criterion=gini, estimator__max_depth=11, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   3.2s
# [CV] END estimator__ccp_alpha=0.03800123615200182, estimator__criterion=entropy, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=13, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   5.0s
# [CV] END estimator__ccp_alpha=0.02054791711545146, estimator__criterion=gini, estimator__max_depth=11, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   4.2s
# [CV] END estimator__ccp_alpha=0.02054791711545146, estimator__criterion=gini, estimator__max_depth=11, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   4.7s
# [CV] END estimator__ccp_alpha=0.03800123615200182, estimator__criterion=entropy, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=13, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   5.5s
# [CV] END estimator__ccp_alpha=0.03800123615200182, estimator__criterion=entropy, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=13, estimator__min_samples_split=8, estimator__n_estimators=200; total time=   5.2s
# [CV] END estimator__ccp_alpha=0.00011510715355273573, estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=14, estimator__n_estimators=200; total time=   2.0s
# [CV] END estimator__ccp_alpha=0.00011510715355273573, estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=14, estimator__n_estimators=200; total time=   2.1s
# [CV] END estimator__ccp_alpha=0.00011510715355273573, estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=14, estimator__n_estimators=200; total time=   2.1s
# [CV] END estimator__ccp_alpha=0.00011510715355273573, estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=14, estimator__n_estimators=200; total time=   2.0s
# [CV] END estimator__ccp_alpha=0.00011510715355273573, estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__min_samples_leaf=5, estimator__min_samples_split=14, estimator__n_estimators=200; total time=   2.4s
# [CV] END estimator__ccp_alpha=0.02054791711545146, estimator__criterion=gini, estimator__max_depth=11, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=3, estimator__n_estimators=200; total time=   3.2s
# [CV] END estimator__ccp_alpha=0.14810897381660948, estimator__criterion=entropy, estimator__max_depth=41, estimator__max_features=sqrt, estimator__min_samples_leaf=10, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=0.05374685867779909, estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   5.6s
# [CV] END estimator__ccp_alpha=0.14810897381660948, estimator__criterion=entropy, estimator__max_depth=41, estimator__max_features=sqrt, estimator__min_samples_leaf=10, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   6.4s
# [CV] END estimator__ccp_alpha=0.14810897381660948, estimator__criterion=entropy, estimator__max_depth=41, estimator__max_features=sqrt, estimator__min_samples_leaf=10, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   7.0s
# [CV] END estimator__ccp_alpha=0.14810897381660948, estimator__criterion=entropy, estimator__max_depth=41, estimator__max_features=sqrt, estimator__min_samples_leaf=10, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   6.9s
# [CV] END estimator__ccp_alpha=0.05374685867779909, estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   6.2s
# [CV] END estimator__ccp_alpha=0.05374685867779909, estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   6.5s
# [CV] END estimator__ccp_alpha=0.05374685867779909, estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   6.5s
# [CV] END estimator__ccp_alpha=9.417974903747706e-05, estimator__criterion=log_loss, estimator__max_depth=41, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=18, estimator__n_estimators=200; total time=   6.0s
# [CV] END estimator__ccp_alpha=0.14810897381660948, estimator__criterion=entropy, estimator__max_depth=41, estimator__max_features=sqrt, estimator__min_samples_leaf=10, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   7.0s
# [CV] END estimator__ccp_alpha=9.417974903747706e-05, estimator__criterion=log_loss, estimator__max_depth=41, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=18, estimator__n_estimators=200; total time=   6.5s
# [CV] END estimator__ccp_alpha=9.417974903747706e-05, estimator__criterion=log_loss, estimator__max_depth=41, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=18, estimator__n_estimators=200; total time=   6.6s
# [CV] END estimator__ccp_alpha=0.05374685867779909, estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=log2, estimator__min_samples_leaf=8, estimator__min_samples_split=4, estimator__n_estimators=200; total time=   6.7s
# [CV] END estimator__ccp_alpha=9.417974903747706e-05, estimator__criterion=log_loss, estimator__max_depth=41, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=18, estimator__n_estimators=200; total time=   6.4s
# [CV] END estimator__ccp_alpha=9.417974903747706e-05, estimator__criterion=log_loss, estimator__max_depth=41, estimator__max_features=log2, estimator__min_samples_leaf=11, estimator__min_samples_split=18, estimator__n_estimators=200; total time=   6.5s
# [CV] END estimator__ccp_alpha=3.817964047909528e-05, estimator__criterion=entropy, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   6.5s
# [CV] END estimator__ccp_alpha=3.817964047909528e-05, estimator__criterion=entropy, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   6.6s
# [CV] END estimator__ccp_alpha=3.817964047909528e-05, estimator__criterion=entropy, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   6.4s
# [CV] END estimator__ccp_alpha=3.817964047909528e-05, estimator__criterion=entropy, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   6.2s
# [CV] END estimator__ccp_alpha=0.15505747933727024, estimator__criterion=log_loss, estimator__max_depth=37, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=0.15505747933727024, estimator__criterion=log_loss, estimator__max_depth=37, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   5.9s
# [CV] END estimator__ccp_alpha=3.817964047909528e-05, estimator__criterion=entropy, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=7, estimator__n_estimators=200; total time=   6.7s
# [CV] END estimator__ccp_alpha=0.15505747933727024, estimator__criterion=log_loss, estimator__max_depth=37, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   6.7s
# [CV] END estimator__ccp_alpha=0.15505747933727024, estimator__criterion=log_loss, estimator__max_depth=37, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   6.8s
# [CV] END estimator__ccp_alpha=0.11526524099528986, estimator__criterion=entropy, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=17, estimator__n_estimators=200; total time=   3.6s
# [CV] END estimator__ccp_alpha=0.15505747933727024, estimator__criterion=log_loss, estimator__max_depth=37, estimator__max_features=sqrt, estimator__min_samples_leaf=6, estimator__min_samples_split=11, estimator__n_estimators=200; total time=   4.6s
# [CV] END estimator__ccp_alpha=0.11526524099528986, estimator__criterion=entropy, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=17, estimator__n_estimators=200; total time=   4.8s
# [CV] END estimator__ccp_alpha=0.11526524099528986, estimator__criterion=entropy, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=17, estimator__n_estimators=200; total time=   4.3s
# [CV] END estimator__ccp_alpha=0.11526524099528986, estimator__criterion=entropy, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=17, estimator__n_estimators=200; total time=   4.7s
# [CV] END estimator__ccp_alpha=0.11526524099528986, estimator__criterion=entropy, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=3, estimator__min_samples_split=17, estimator__n_estimators=200; total time=   4.4s
# RandomizedSearchCV(cv=[(array([ 639,  640,  641, ..., 9588, 9589, 9590], shape=(3518,)),
#                         array([1598, 1599, 1600, ..., 8310, 8311, 8312], shape=(1917,))),
#                        (array([ 639,  640,  641, ..., 9588, 9589, 9590], shape=(3518,)),
#                         array([1598, 1599, 1600, ..., 7990, 7991, 7992], shape=(1917,))),
#                        (array([ 639,  640,  641, ..., 9588, 9589, 9590], shape=(3518,)),
#                         array([ 959,  960,  961, ..., 7990, 7991, 7992], shape=(...
#                                         'estimator__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7f1b8949a1d0>,
#                                         'estimator__max_features': ['sqrt',
#                                                                     'log2'],
#                                         'estimator__min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7f1b89542cd0>,
#                                         'estimator__min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7f1b8ca442d0>,
#                                         'estimator__n_estimators': [200]},
#                    scoring='roc_auc', verbose=2)

# %%
results = pd.DataFrame(random_search.cv_results_).sort_values(by="rank_test_score")

# %%
results.head(5)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 244       2.106834      0.131136         0.036123        0.012235
# 146       2.167267      0.162956         0.030442        0.000663
# 22        5.752028      0.246037         0.030641        0.000281
# 88        6.625231      0.329033         0.029779        0.000698
# 13        4.548373      0.204910         0.044239        0.022174
#
#      param_estimator__ccp_alpha param_estimator__criterion  \
# 244                    0.000115                    entropy
# 146                    0.000163                       gini
# 22                     0.058223                    entropy
# 88                     0.077240                    entropy
# 13                     0.022810                       gini
#
#      param_estimator__max_depth param_estimator__max_features  \
# 244                           2                          sqrt
# 146                           3                          sqrt
# 22                           18                          sqrt
# 88                           23                          sqrt
# 13                           11                          sqrt
#
#      param_estimator__min_samples_leaf  param_estimator__min_samples_split  \
# 244                                  5                                  14
# 146                                  8                                  14
# 22                                   6                                   2
# 88                                  15                                   3
# 13                                   5                                   9
#
#      param_estimator__n_estimators  \
# 244                            200
# 146                            200
# 22                             200
# 88                             200
# 13                             200
#
#                                                 params  split0_test_score  \
# 244  {'estimator__ccp_alpha': 0.0001151071535527357...           0.909022
# 146  {'estimator__ccp_alpha': 0.0001634560999475142...           0.901383
# 22   {'estimator__ccp_alpha': 0.0582229531287423, '...           0.893516
# 88   {'estimator__ccp_alpha': 0.07723959535546486, ...           0.897906
# 13   {'estimator__ccp_alpha': 0.022809539117521635,...           0.866517
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 244           0.924109           0.804226           0.417087
# 146           0.864233           0.731859           0.518267
# 22            0.766082           0.750279           0.611505
# 88            0.830970           0.739866           0.543856
# 13            0.785698           0.722663           0.635726
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 244           0.878420         0.786573        0.189302                1
# 146           0.907011         0.784550        0.147431                2
# 22            0.875999         0.779476        0.101556                3
# 88            0.882745         0.779069        0.129943                4
# 13            0.880157         0.778152        0.091252                5

# %%
results.loc[22]
# Out:
# mean_fit_time                                                                  5.752028
# std_fit_time                                                                   0.246037
# mean_score_time                                                                0.030641
# std_score_time                                                                 0.000281
# param_estimator__ccp_alpha                                                     0.058223
# param_estimator__criterion                                                      entropy
# param_estimator__max_depth                                                           18
# param_estimator__max_features                                                      sqrt
# param_estimator__min_samples_leaf                                                     6
# param_estimator__min_samples_split                                                    2
# param_estimator__n_estimators                                                       200
# params                                {'estimator__ccp_alpha': 0.0582229531287423, '...
# split0_test_score                                                              0.893516
# split1_test_score                                                              0.766082
# split2_test_score                                                              0.750279
# split3_test_score                                                              0.611505
# split4_test_score                                                              0.875999
# mean_test_score                                                                0.779476
# std_test_score                                                                 0.101556
# rank_test_score                                                                       3
# Name: 22, dtype: object

# %%
best_params = results.loc[22]["params"]

# %%
best_params.values()
# Out:
# dict_values([np.float64(0.0582229531287423), 'entropy', 18, 'sqrt', 6, 2, 200])

# %%
keys = []
for i in best_params.keys():
    keys.append(i.replace("estimator__", ""))

# %%
best_params = {k: i for (k,i) in zip(keys, best_params.values())}

# %%
best_params
# Out:
# {'ccp_alpha': np.float64(0.0582229531287423),
#  'criterion': 'entropy',
#  'max_depth': 18,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 6,
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
from sklearn.metrics import roc_auc_score

#### WITHOUT COMBINEDS
cvs = [get_cv_splits(sampler=sampler, df=df, run=run,
 healthy_bearing_ids=healthy_bearing_ids, outer_bearing_ids=outer_bearing_ids,
  inner_bearing_ids=inner_bearing_ids, use_combined=False, on_train=False)
 for run in range(5,105)]

aucs = []
for cv in cvs:

    X_train = X.iloc[cv[0]]
    X_test = X.iloc[cv[1]]

    y_train = y.iloc[cv[0]]
    y_test = y.iloc[cv[1]]

    model = MultiOutputClassifier(RandomForestClassifier(random_state=42, **best_params), n_jobs=-1)

    model.fit(X_train, y_train)
    y_probas = model.predict_proba(X_test)
    proba_outer = y_probas[1][:, 1]
    proba_inner = y_probas[0][:, 1]

    auroc_outer = roc_auc_score(y_test["outer"], proba_outer)
    auroc_inner = roc_auc_score(y_test["inner"], proba_inner)

    macro_auc = np.mean([auroc_outer, auroc_inner])
    print(f"Macro AUC: {macro_auc:.4f} | Outer AUC: {auroc_outer:.4f} | Inner AUC: {auroc_inner:.4f}")
    aucs.append([macro_auc, auroc_outer, auroc_inner])
# Out:
# Macro AUC: 0.7553 | Outer AUC: 0.7540 | Inner AUC: 0.7566
# Macro AUC: 0.8695 | Outer AUC: 0.7990 | Inner AUC: 0.9399
# Macro AUC: 0.3801 | Outer AUC: 0.3969 | Inner AUC: 0.3633
# Macro AUC: 0.8487 | Outer AUC: 0.7462 | Inner AUC: 0.9513
# Macro AUC: 0.6929 | Outer AUC: 0.6347 | Inner AUC: 0.7512
# Macro AUC: 0.7232 | Outer AUC: 0.7065 | Inner AUC: 0.7399
# Macro AUC: 0.6385 | Outer AUC: 0.4150 | Inner AUC: 0.8620
# Macro AUC: 0.2169 | Outer AUC: 0.0170 | Inner AUC: 0.4167
# Macro AUC: 0.8983 | Outer AUC: 0.8223 | Inner AUC: 0.9743
# Macro AUC: 0.8954 | Outer AUC: 0.8413 | Inner AUC: 0.9496
# Macro AUC: 0.7095 | Outer AUC: 0.5648 | Inner AUC: 0.8543
# Macro AUC: 0.4692 | Outer AUC: 0.2150 | Inner AUC: 0.7233
# Macro AUC: 0.7376 | Outer AUC: 0.7319 | Inner AUC: 0.7432
# Macro AUC: 0.8959 | Outer AUC: 0.8544 | Inner AUC: 0.9373
# Macro AUC: 0.8395 | Outer AUC: 0.8145 | Inner AUC: 0.8646
# Macro AUC: 0.8619 | Outer AUC: 0.8343 | Inner AUC: 0.8895
# Macro AUC: 0.5426 | Outer AUC: 0.7402 | Inner AUC: 0.3450
# Macro AUC: 0.3264 | Outer AUC: 0.5630 | Inner AUC: 0.0897
# Macro AUC: 0.8936 | Outer AUC: 0.8616 | Inner AUC: 0.9255
# Macro AUC: 0.9072 | Outer AUC: 0.9495 | Inner AUC: 0.8649
# Macro AUC: 0.7580 | Outer AUC: 0.7104 | Inner AUC: 0.8056
# Macro AUC: 0.8567 | Outer AUC: 0.8413 | Inner AUC: 0.8722
# Macro AUC: 0.7333 | Outer AUC: 0.6379 | Inner AUC: 0.8287
# Macro AUC: 0.9030 | Outer AUC: 0.8966 | Inner AUC: 0.9094
# Macro AUC: 0.4877 | Outer AUC: 0.6820 | Inner AUC: 0.2933
# Macro AUC: 0.7022 | Outer AUC: 0.5989 | Inner AUC: 0.8056
# Macro AUC: 0.8222 | Outer AUC: 0.7341 | Inner AUC: 0.9102
# Macro AUC: 0.8899 | Outer AUC: 0.8587 | Inner AUC: 0.9210
# Macro AUC: 0.5864 | Outer AUC: 0.3136 | Inner AUC: 0.8593
# Macro AUC: 0.7560 | Outer AUC: 0.7394 | Inner AUC: 0.7727
# Macro AUC: 0.3086 | Outer AUC: 0.2362 | Inner AUC: 0.3811
# Macro AUC: 0.8788 | Outer AUC: 0.8348 | Inner AUC: 0.9229
# Macro AUC: 0.5518 | Outer AUC: 0.2640 | Inner AUC: 0.8397
# Macro AUC: 0.7852 | Outer AUC: 0.8315 | Inner AUC: 0.7388
# Macro AUC: 0.6613 | Outer AUC: 0.5940 | Inner AUC: 0.7286
# Macro AUC: 0.6340 | Outer AUC: 0.6127 | Inner AUC: 0.6552
# Macro AUC: 0.8926 | Outer AUC: 0.8717 | Inner AUC: 0.9134
# Macro AUC: 0.3894 | Outer AUC: 0.1942 | Inner AUC: 0.5845
# Macro AUC: 0.8528 | Outer AUC: 0.8657 | Inner AUC: 0.8399
# Macro AUC: 0.6305 | Outer AUC: 0.4934 | Inner AUC: 0.7677
# Macro AUC: 0.6903 | Outer AUC: 0.6911 | Inner AUC: 0.6895
# Macro AUC: 0.9152 | Outer AUC: 0.9060 | Inner AUC: 0.9243
# Macro AUC: 0.7286 | Outer AUC: 0.6890 | Inner AUC: 0.7681
# Macro AUC: 0.3107 | Outer AUC: 0.2494 | Inner AUC: 0.3721
# Macro AUC: 0.8651 | Outer AUC: 0.8603 | Inner AUC: 0.8700
# Macro AUC: 0.7659 | Outer AUC: 0.6461 | Inner AUC: 0.8856
# Macro AUC: 0.7302 | Outer AUC: 0.6950 | Inner AUC: 0.7654
# Macro AUC: 0.9021 | Outer AUC: 0.8475 | Inner AUC: 0.9568
# Macro AUC: 0.4187 | Outer AUC: 0.2157 | Inner AUC: 0.6218
# Macro AUC: 0.7308 | Outer AUC: 0.8256 | Inner AUC: 0.6361
# Macro AUC: 0.6340 | Outer AUC: 0.5119 | Inner AUC: 0.7561
# Macro AUC: 0.5552 | Outer AUC: 0.3074 | Inner AUC: 0.8030
# Macro AUC: 0.4342 | Outer AUC: 0.7064 | Inner AUC: 0.1620
# Macro AUC: 0.6983 | Outer AUC: 0.6410 | Inner AUC: 0.7555
# Macro AUC: 0.7880 | Outer AUC: 0.6991 | Inner AUC: 0.8770
# Macro AUC: 0.8400 | Outer AUC: 0.7938 | Inner AUC: 0.8862
# Macro AUC: 0.7839 | Outer AUC: 0.7311 | Inner AUC: 0.8368
# Macro AUC: 0.4109 | Outer AUC: 0.2131 | Inner AUC: 0.6086
# Macro AUC: 0.3162 | Outer AUC: 0.2587 | Inner AUC: 0.3737
# Macro AUC: 0.3246 | Outer AUC: 0.2278 | Inner AUC: 0.4213
# Macro AUC: 0.5580 | Outer AUC: 0.3825 | Inner AUC: 0.7335
# Macro AUC: 0.6022 | Outer AUC: 0.3509 | Inner AUC: 0.8536
# Macro AUC: 0.6911 | Outer AUC: 0.5519 | Inner AUC: 0.8302
# Macro AUC: 0.9257 | Outer AUC: 0.9167 | Inner AUC: 0.9347
# Macro AUC: 0.5428 | Outer AUC: 0.5500 | Inner AUC: 0.5356
# Macro AUC: 0.5817 | Outer AUC: 0.4645 | Inner AUC: 0.6989
# Macro AUC: 0.7477 | Outer AUC: 0.6931 | Inner AUC: 0.8024
# Macro AUC: 0.4755 | Outer AUC: 0.0842 | Inner AUC: 0.8667
# Macro AUC: 0.6278 | Outer AUC: 0.4991 | Inner AUC: 0.7564
# Macro AUC: 0.1234 | Outer AUC: 0.1246 | Inner AUC: 0.1223
# Macro AUC: 0.3946 | Outer AUC: 0.1673 | Inner AUC: 0.6219
# Macro AUC: 0.8129 | Outer AUC: 0.7267 | Inner AUC: 0.8990
# Macro AUC: 0.2341 | Outer AUC: 0.0538 | Inner AUC: 0.4145
# Macro AUC: 0.9059 | Outer AUC: 0.8527 | Inner AUC: 0.9591
# Macro AUC: 0.4215 | Outer AUC: 0.2194 | Inner AUC: 0.6235
# Macro AUC: 0.5516 | Outer AUC: 0.7946 | Inner AUC: 0.3085
# Macro AUC: 0.2956 | Outer AUC: 0.1214 | Inner AUC: 0.4699
# Macro AUC: 0.7215 | Outer AUC: 0.6402 | Inner AUC: 0.8028
# Macro AUC: 0.8354 | Outer AUC: 0.7432 | Inner AUC: 0.9276
# Macro AUC: 0.6898 | Outer AUC: 0.6437 | Inner AUC: 0.7359
# Macro AUC: 0.8348 | Outer AUC: 0.7868 | Inner AUC: 0.8828
# Macro AUC: 0.7516 | Outer AUC: 0.7046 | Inner AUC: 0.7986
# Macro AUC: 0.7930 | Outer AUC: 0.7285 | Inner AUC: 0.8575
# Macro AUC: 0.2573 | Outer AUC: 0.0351 | Inner AUC: 0.4796
# Macro AUC: 0.9281 | Outer AUC: 0.9359 | Inner AUC: 0.9202
# Macro AUC: 0.6544 | Outer AUC: 0.5728 | Inner AUC: 0.7360
# Macro AUC: 0.5050 | Outer AUC: 0.4527 | Inner AUC: 0.5573
# Macro AUC: 0.3894 | Outer AUC: 0.3084 | Inner AUC: 0.4703
# Macro AUC: 0.6796 | Outer AUC: 0.4664 | Inner AUC: 0.8927
# Macro AUC: 0.8234 | Outer AUC: 0.7517 | Inner AUC: 0.8950
# Macro AUC: 0.9216 | Outer AUC: 0.8945 | Inner AUC: 0.9488
# Macro AUC: 0.6996 | Outer AUC: 0.7661 | Inner AUC: 0.6330
# Macro AUC: 0.9264 | Outer AUC: 0.8856 | Inner AUC: 0.9671
# Macro AUC: 0.7801 | Outer AUC: 0.7261 | Inner AUC: 0.8341
# Macro AUC: 0.7116 | Outer AUC: 0.7082 | Inner AUC: 0.7149
# Macro AUC: 0.8912 | Outer AUC: 0.7950 | Inner AUC: 0.9874
# Macro AUC: 0.8163 | Outer AUC: 0.7904 | Inner AUC: 0.8422
# Macro AUC: 0.7934 | Outer AUC: 0.7029 | Inner AUC: 0.8838
# Macro AUC: 0.9034 | Outer AUC: 0.8107 | Inner AUC: 0.9962
# Macro AUC: 0.7005 | Outer AUC: 0.5631 | Inner AUC: 0.8378

# %%
macro_aucs = [i[0] for i in aucs]
np.mean(macro_aucs), np.std(macro_aucs)
# Out:
# (np.float64(0.6752505168952146), np.float64(0.20016290954185018))

# %%
from sklearn.metrics import roc_auc_score

#### WITH COMBINED 
cvs = [get_cv_splits(sampler=sampler, df=df, run=run,
 healthy_bearing_ids=healthy_bearing_ids, outer_bearing_ids=outer_bearing_ids,
  inner_bearing_ids=inner_bearing_ids, use_combined=True, on_train=False)
 for run in range(5,105)]

aucs = []
for cv in cvs:

    X_train = X.iloc[cv[0]]
    X_test = X.iloc[cv[1]]

    y_train = y.iloc[cv[0]]
    y_test = y.iloc[cv[1]]

    model = MultiOutputClassifier(RandomForestClassifier(random_state=42, **best_params), n_jobs=-1)

    model.fit(X_train, y_train)
    y_probas = model.predict_proba(X_test)
    proba_outer = y_probas[1][:, 1]
    proba_inner = y_probas[0][:, 1]

    auroc_outer = roc_auc_score(y_test["outer"], proba_outer)
    auroc_inner = roc_auc_score(y_test["inner"], proba_inner)

    macro_auc = np.mean([auroc_outer, auroc_inner])
    print(f"Macro AUC: {macro_auc:.4f} | Outer AUC: {auroc_outer:.4f} | Inner AUC: {auroc_inner:.4f}")
    aucs.append([macro_auc, auroc_outer, auroc_inner])
# Out:
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Macro AUC: 0.7823 | Outer AUC: 0.8516 | Inner AUC: 0.7129
# Macro AUC: 0.7930 | Outer AUC: 0.8054 | Inner AUC: 0.7807
# Macro AUC: 0.4645 | Outer AUC: 0.6668 | Inner AUC: 0.2622
# Macro AUC: 0.8537 | Outer AUC: 0.7580 | Inner AUC: 0.9494
# Macro AUC: 0.7394 | Outer AUC: 0.8205 | Inner AUC: 0.6583
# Macro AUC: 0.6680 | Outer AUC: 0.7897 | Inner AUC: 0.5462
# Macro AUC: 0.6576 | Outer AUC: 0.6736 | Inner AUC: 0.6416
# Macro AUC: 0.3629 | Outer AUC: 0.1923 | Inner AUC: 0.5335
# Macro AUC: 0.8404 | Outer AUC: 0.8456 | Inner AUC: 0.8352
# Macro AUC: 0.8442 | Outer AUC: 0.8676 | Inner AUC: 0.8207
# Macro AUC: 0.7743 | Outer AUC: 0.7592 | Inner AUC: 0.7894
# Macro AUC: 0.5256 | Outer AUC: 0.2900 | Inner AUC: 0.7612
# Macro AUC: 0.7145 | Outer AUC: 0.8806 | Inner AUC: 0.5483
# Macro AUC: 0.8562 | Outer AUC: 0.8462 | Inner AUC: 0.8662
# Macro AUC: 0.7232 | Outer AUC: 0.8848 | Inner AUC: 0.5616
# Macro AUC: 0.7855 | Outer AUC: 0.8530 | Inner AUC: 0.7180
# Macro AUC: 0.6402 | Outer AUC: 0.8277 | Inner AUC: 0.4528
# Macro AUC: 0.4458 | Outer AUC: 0.7595 | Inner AUC: 0.1320
# Macro AUC: 0.8920 | Outer AUC: 0.8894 | Inner AUC: 0.8947
# Macro AUC: 0.8916 | Outer AUC: 0.9434 | Inner AUC: 0.8398
# Macro AUC: 0.7727 | Outer AUC: 0.7826 | Inner AUC: 0.7629
# Macro AUC: 0.7538 | Outer AUC: 0.8445 | Inner AUC: 0.6631
# Macro AUC: 0.6160 | Outer AUC: 0.6700 | Inner AUC: 0.5621
# Macro AUC: 0.8649 | Outer AUC: 0.9025 | Inner AUC: 0.8273
# Macro AUC: 0.5160 | Outer AUC: 0.7468 | Inner AUC: 0.2851
# Macro AUC: 0.6542 | Outer AUC: 0.7871 | Inner AUC: 0.5213
# Macro AUC: 0.6966 | Outer AUC: 0.7347 | Inner AUC: 0.6584
# Macro AUC: 0.8437 | Outer AUC: 0.8548 | Inner AUC: 0.8325
# Macro AUC: 0.5912 | Outer AUC: 0.5977 | Inner AUC: 0.5847
# Macro AUC: 0.7696 | Outer AUC: 0.8746 | Inner AUC: 0.6647
# Macro AUC: 0.4248 | Outer AUC: 0.5518 | Inner AUC: 0.2978
# Macro AUC: 0.8282 | Outer AUC: 0.8643 | Inner AUC: 0.7922
# Macro AUC: 0.5570 | Outer AUC: 0.5371 | Inner AUC: 0.5769
# Macro AUC: 0.6963 | Outer AUC: 0.8561 | Inner AUC: 0.5366
# Macro AUC: 0.6512 | Outer AUC: 0.7291 | Inner AUC: 0.5732
# Macro AUC: 0.6468 | Outer AUC: 0.7960 | Inner AUC: 0.4976
# Macro AUC: 0.8721 | Outer AUC: 0.8939 | Inner AUC: 0.8502
# Macro AUC: 0.4635 | Outer AUC: 0.3039 | Inner AUC: 0.6230
# Macro AUC: 0.8394 | Outer AUC: 0.9457 | Inner AUC: 0.7331
# Macro AUC: 0.5897 | Outer AUC: 0.7091 | Inner AUC: 0.4703
# Macro AUC: 0.6834 | Outer AUC: 0.8151 | Inner AUC: 0.5517
# Macro AUC: 0.9000 | Outer AUC: 0.9023 | Inner AUC: 0.8976
# Macro AUC: 0.7019 | Outer AUC: 0.7969 | Inner AUC: 0.6069
# Macro AUC: 0.4440 | Outer AUC: 0.5546 | Inner AUC: 0.3333
# Macro AUC: 0.8331 | Outer AUC: 0.8109 | Inner AUC: 0.8553
# Macro AUC: 0.7029 | Outer AUC: 0.7126 | Inner AUC: 0.6931
# Macro AUC: 0.6880 | Outer AUC: 0.7982 | Inner AUC: 0.5778
# Macro AUC: 0.8964 | Outer AUC: 0.8525 | Inner AUC: 0.9404
# Macro AUC: 0.5191 | Outer AUC: 0.3177 | Inner AUC: 0.7204
# Macro AUC: 0.7386 | Outer AUC: 0.8737 | Inner AUC: 0.6035
# Macro AUC: 0.6224 | Outer AUC: 0.7130 | Inner AUC: 0.5317
# Macro AUC: 0.5970 | Outer AUC: 0.5973 | Inner AUC: 0.5966
# Macro AUC: 0.5533 | Outer AUC: 0.8179 | Inner AUC: 0.2888
# Macro AUC: 0.6713 | Outer AUC: 0.7926 | Inner AUC: 0.5499
# Macro AUC: 0.7090 | Outer AUC: 0.8408 | Inner AUC: 0.5773
# Macro AUC: 0.8379 | Outer AUC: 0.8463 | Inner AUC: 0.8295
# Macro AUC: 0.6756 | Outer AUC: 0.7297 | Inner AUC: 0.6215
# Macro AUC: 0.5054 | Outer AUC: 0.3031 | Inner AUC: 0.7077
# Macro AUC: 0.4316 | Outer AUC: 0.5643 | Inner AUC: 0.2990
# Macro AUC: 0.4334 | Outer AUC: 0.5514 | Inner AUC: 0.3154
# Macro AUC: 0.5107 | Outer AUC: 0.3877 | Inner AUC: 0.6337
# Macro AUC: 0.5848 | Outer AUC: 0.5371 | Inner AUC: 0.6324
# Macro AUC: 0.7281 | Outer AUC: 0.7715 | Inner AUC: 0.6848
# Macro AUC: 0.8779 | Outer AUC: 0.9352 | Inner AUC: 0.8206
# Macro AUC: 0.5740 | Outer AUC: 0.5284 | Inner AUC: 0.6196
# Macro AUC: 0.7244 | Outer AUC: 0.7077 | Inner AUC: 0.7412
# Macro AUC: 0.7320 | Outer AUC: 0.8062 | Inner AUC: 0.6578
# Macro AUC: 0.5450 | Outer AUC: 0.4587 | Inner AUC: 0.6313
# Macro AUC: 0.7097 | Outer AUC: 0.7356 | Inner AUC: 0.6837
# Macro AUC: 0.3218 | Outer AUC: 0.4791 | Inner AUC: 0.1646
# Macro AUC: 0.5869 | Outer AUC: 0.4835 | Inner AUC: 0.6903
# Macro AUC: 0.7451 | Outer AUC: 0.8022 | Inner AUC: 0.6880
# Macro AUC: 0.3186 | Outer AUC: 0.1756 | Inner AUC: 0.4616
# Macro AUC: 0.9034 | Outer AUC: 0.8567 | Inner AUC: 0.9501
# Macro AUC: 0.4749 | Outer AUC: 0.2998 | Inner AUC: 0.6499
# Macro AUC: 0.6661 | Outer AUC: 0.8083 | Inner AUC: 0.5240
# Macro AUC: 0.3623 | Outer AUC: 0.2125 | Inner AUC: 0.5121
# Macro AUC: 0.7019 | Outer AUC: 0.8038 | Inner AUC: 0.6001
# Macro AUC: 0.8522 | Outer AUC: 0.8785 | Inner AUC: 0.8259
# Macro AUC: 0.6640 | Outer AUC: 0.7984 | Inner AUC: 0.5296
# Macro AUC: 0.8085 | Outer AUC: 0.8581 | Inner AUC: 0.7589
# Macro AUC: 0.6720 | Outer AUC: 0.7904 | Inner AUC: 0.5535
# Macro AUC: 0.7620 | Outer AUC: 0.8247 | Inner AUC: 0.6992
# Macro AUC: 0.4056 | Outer AUC: 0.4382 | Inner AUC: 0.3730
# Macro AUC: 0.8342 | Outer AUC: 0.9459 | Inner AUC: 0.7226
# Macro AUC: 0.6254 | Outer AUC: 0.7679 | Inner AUC: 0.4829
# Macro AUC: 0.6470 | Outer AUC: 0.6971 | Inner AUC: 0.5970
# Macro AUC: 0.4724 | Outer AUC: 0.6008 | Inner AUC: 0.3441
# Macro AUC: 0.7589 | Outer AUC: 0.6972 | Inner AUC: 0.8205
# Macro AUC: 0.7548 | Outer AUC: 0.7271 | Inner AUC: 0.7825
# Macro AUC: 0.8619 | Outer AUC: 0.9184 | Inner AUC: 0.8054
# Macro AUC: 0.7500 | Outer AUC: 0.7862 | Inner AUC: 0.7138
# Macro AUC: 0.8532 | Outer AUC: 0.9310 | Inner AUC: 0.7754
# Macro AUC: 0.7686 | Outer AUC: 0.8156 | Inner AUC: 0.7216
# Macro AUC: 0.6472 | Outer AUC: 0.7938 | Inner AUC: 0.5007
# Macro AUC: 0.8606 | Outer AUC: 0.8405 | Inner AUC: 0.8807
# Macro AUC: 0.7780 | Outer AUC: 0.8566 | Inner AUC: 0.6994
# Macro AUC: 0.6622 | Outer AUC: 0.7079 | Inner AUC: 0.6164
# Macro AUC: 0.8530 | Outer AUC: 0.8849 | Inner AUC: 0.8211
# Macro AUC: 0.7603 | Outer AUC: 0.7585 | Inner AUC: 0.7621

# %%
macro_aucs = [i[0] for i in aucs]
np.mean(macro_aucs), np.std(macro_aucs)
# Out:
# (np.float64(0.6816634324097492), np.float64(0.14772935620341357))

# %% [markdown]
# ## SVM

# %%
cvs = [get_cv_splits(sampler=sampler, df=df, run=run,
 healthy_bearing_ids=healthy_bearing_ids, outer_bearing_ids=outer_bearing_ids,
  inner_bearing_ids=inner_bearing_ids, use_combined=False, on_train=False)
 for run in range(5)]

# %%
from sklearn.svm import SVC

random_search = RandomizedSearchCV(
    estimator=MultiOutputClassifier(SVC(probability=True)),
    param_distributions={
        "estimator__C": loguniform(1e-3, 1e3),
        "estimator__gamma": ["scale", "auto"],
        "estimator__kernel": ["rbf"],
    },
    n_iter=250,
    cv=cvs,
    scoring="roc_auc",
    verbose=2,
    n_jobs=-1,
)

random_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 250 candidates, totalling 1250 fits
# [CV] END estimator__C=5.67849118947293, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.2s
# [CV] END estimator__C=5.67849118947293, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.2s
# [CV] END estimator__C=5.67849118947293, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.4s
# [CV] END estimator__C=5.67849118947293, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.7s
# [CV] END estimator__C=1.7284155717424479, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.8s
# [CV] END estimator__C=73.8235760253899, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=1.7284155717424479, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=1.7284155717424479, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=14.69716572373262, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=73.8235760253899, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=14.69716572373262, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.3s
# [CV] END estimator__C=73.8235760253899, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.4s
# [CV] END estimator__C=14.69716572373262, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=73.8235760253899, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=73.8235760253899, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.7s
# [CV] END estimator__C=14.69716572373262, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.7s
# [CV] END estimator__C=5.67849118947293, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.8s
# [CV] END estimator__C=1.7284155717424479, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.9s
# [CV] END estimator__C=14.69716572373262, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.2s
# [CV] END estimator__C=1.7284155717424479, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.0s
# [CV] END estimator__C=0.002179412971041942, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=0.002179412971041942, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.3s
# [CV] END estimator__C=0.002179412971041942, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=0.002179412971041942, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.5s
# [CV] END estimator__C=92.88195600785708, estimator__gamma=scale, estimator__kernel=rbf; total time=   3.6s
# [CV] END estimator__C=92.88195600785708, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=92.88195600785708, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.1s
# [CV] END estimator__C=0.479311556030871, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.8s
# [CV] END estimator__C=92.88195600785708, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=92.88195600785708, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=0.479311556030871, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.5s
# [CV] END estimator__C=0.002179412971041942, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.4s
# [CV] END estimator__C=0.479311556030871, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.479311556030871, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.8s
# [CV] END estimator__C=0.479311556030871, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.1s
# [CV] END estimator__C=0.014545424206514999, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=0.014545424206514999, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=0.014545424206514999, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=0.014545424206514999, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.8s
# [CV] END estimator__C=0.19208946079761974, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.2s
# [CV] END estimator__C=0.19208946079761974, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=0.19208946079761974, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.6s
# [CV] END estimator__C=0.5063617824370225, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=0.014545424206514999, estimator__gamma=scale, estimator__kernel=rbf; total time=   9.5s
# [CV] END estimator__C=0.5063617824370225, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=0.19208946079761974, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.7s
# [CV] END estimator__C=0.19208946079761974, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.9s
# [CV] END estimator__C=0.5063617824370225, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.2s
# [CV] END estimator__C=178.43155688806849, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.1s
# [CV] END estimator__C=0.5063617824370225, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=178.43155688806849, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.8s
# [CV] END estimator__C=178.43155688806849, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=178.43155688806849, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=178.43155688806849, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.1s
# [CV] END estimator__C=0.5063617824370225, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.4s
# [CV] END estimator__C=0.003570642936502016, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=0.21677373187799023, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.1s
# [CV] END estimator__C=0.003570642936502016, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=0.003570642936502016, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.5s
# [CV] END estimator__C=0.21677373187799023, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.6s
# [CV] END estimator__C=0.003570642936502016, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.5s
# [CV] END estimator__C=6.652461868736555, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.2s
# [CV] END estimator__C=0.003570642936502016, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.2s
# [CV] END estimator__C=0.21677373187799023, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=0.21677373187799023, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=6.652461868736555, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.5s
# [CV] END estimator__C=6.652461868736555, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=0.21677373187799023, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.0s
# [CV] END estimator__C=6.652461868736555, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.5s
# [CV] END estimator__C=6.652461868736555, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.7s
# [CV] END estimator__C=0.03380907916529295, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.3s
# [CV] END estimator__C=0.03380907916529295, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=20.880938278379052, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.7s
# [CV] END estimator__C=120.35265423793633, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.4s
# [CV] END estimator__C=0.03380907916529295, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.4s
# [CV] END estimator__C=20.880938278379052, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=0.03380907916529295, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.03380907916529295, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=0.0038784147536780962, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=0.0038784147536780962, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=20.880938278379052, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.4s
# [CV] END estimator__C=120.35265423793633, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.3s
# [CV] END estimator__C=0.0038784147536780962, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=120.35265423793633, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.5s
# [CV] END estimator__C=20.880938278379052, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=0.0038784147536780962, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=2.36528481832862, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.5s
# [CV] END estimator__C=120.35265423793633, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=2.36528481832862, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.7s
# [CV] END estimator__C=20.880938278379052, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.5s
# [CV] END estimator__C=2.36528481832862, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.0s
# [CV] END estimator__C=2.36528481832862, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.3s
# [CV] END estimator__C=2.36528481832862, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=120.35265423793633, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.3s
# [CV] END estimator__C=0.0038784147536780962, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.9s
# [CV] END estimator__C=302.169925773343, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.7s
# [CV] END estimator__C=302.169925773343, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=206.3439622732935, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=206.3439622732935, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.5s
# [CV] END estimator__C=302.169925773343, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.6s
# [CV] END estimator__C=206.3439622732935, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.9s
# [CV] END estimator__C=206.3439622732935, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.4s
# [CV] END estimator__C=0.7116081432189686, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.6s
# [CV] END estimator__C=302.169925773343, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.0s
# [CV] END estimator__C=0.7116081432189686, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=0.7116081432189686, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=206.3439622732935, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.6s
# [CV] END estimator__C=302.169925773343, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=0.7116081432189686, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=0.7116081432189686, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.7s
# [CV] END estimator__C=0.001151045537476893, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.1s
# [CV] END estimator__C=0.001151045537476893, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=2.8357841267386275, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.5s
# [CV] END estimator__C=2.8357841267386275, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=0.001151045537476893, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=2.8357841267386275, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.4s
# [CV] END estimator__C=0.001151045537476893, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.6s
# [CV] END estimator__C=0.001151045537476893, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.5s
# [CV] END estimator__C=2.8357841267386275, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=2.8357841267386275, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=7.2576086748307045, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.0s
# [CV] END estimator__C=6.446865344169827, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.1s
# [CV] END estimator__C=6.446865344169827, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.1s
# [CV] END estimator__C=7.2576086748307045, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=6.446865344169827, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.4s
# [CV] END estimator__C=7.2576086748307045, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.5s
# [CV] END estimator__C=7.2576086748307045, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.3s
# [CV] END estimator__C=6.446865344169827, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=7.2576086748307045, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.2s
# [CV] END estimator__C=51.79940231642635, estimator__gamma=scale, estimator__kernel=rbf; total time=   3.9s
# [CV] END estimator__C=6.446865344169827, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.9s
# [CV] END estimator__C=51.79940231642635, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.1s
# [CV] END estimator__C=879.4250436477384, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.7s
# [CV] END estimator__C=51.79940231642635, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.2s
# [CV] END estimator__C=879.4250436477384, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.6s[CV] END estimator__C=51.79940231642635, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.4s
#
# [CV] END estimator__C=51.79940231642635, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.4s
# [CV] END estimator__C=879.4250436477384, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.1s
# [CV] END estimator__C=879.4250436477384, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.4s
# [CV] END estimator__C=0.01775148238982674, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=879.4250436477384, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.8s
# [CV] END estimator__C=67.18088510128162, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=30.795267645877786, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=0.01775148238982674, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=30.795267645877786, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.9s
# [CV] END estimator__C=0.01775148238982674, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=30.795267645877786, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.1s
# [CV] END estimator__C=0.01775148238982674, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.01775148238982674, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=67.18088510128162, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=67.18088510128162, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=67.18088510128162, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=30.795267645877786, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.6s
# [CV] END estimator__C=30.795267645877786, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=3.635974598303908, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.9s
# [CV] END estimator__C=3.635974598303908, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=67.18088510128162, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.2s
# [CV] END estimator__C=3.635974598303908, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.6s
# [CV] END estimator__C=3.635974598303908, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=3.635974598303908, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.5s
# [CV] END estimator__C=164.08482111948564, estimator__gamma=scale, estimator__kernel=rbf; total time=   3.6s
# [CV] END estimator__C=96.18515181761961, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.4s
# [CV] END estimator__C=164.08482111948564, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.1s
# [CV] END estimator__C=96.18515181761961, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.7s
# [CV] END estimator__C=164.08482111948564, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=96.18515181761961, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.1s
# [CV] END estimator__C=96.18515181761961, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=164.08482111948564, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=164.08482111948564, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.5s
# [CV] END estimator__C=96.18515181761961, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.5s
# [CV] END estimator__C=0.11113427825504091, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=0.11113427825504091, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.5s
# [CV] END estimator__C=0.11113427825504091, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.8s
# [CV] END estimator__C=0.11113427825504091, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=0.11113427825504091, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=0.0015421267995267998, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.0s
# [CV] END estimator__C=0.6420143028071964, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.6s
# [CV] END estimator__C=0.0015421267995267998, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.7s
# [CV] END estimator__C=0.0014724219651750204, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=0.6420143028071964, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.0014724219651750204, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=0.0015421267995267998, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.9s
# [CV] END estimator__C=0.0015421267995267998, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.7s
# [CV] END estimator__C=0.0014724219651750204, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.6s
# [CV] END estimator__C=0.0014724219651750204, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.5s
# [CV] END estimator__C=0.6420143028071964, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.6s
# [CV] END estimator__C=0.0015421267995267998, estimator__gamma=scale, estimator__kernel=rbf; total time=   9.0s
# [CV] END estimator__C=0.6420143028071964, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.3s
# [CV] END estimator__C=0.6420143028071964, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.4s
# [CV] END estimator__C=0.0014724219651750204, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.5s
# [CV] END estimator__C=0.15031495334461742, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.15031495334461742, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.0s
# [CV] END estimator__C=0.15031495334461742, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.5s
# [CV] END estimator__C=0.15031495334461742, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=0.15031495334461742, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=0.8757696273654054, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.3s
# [CV] END estimator__C=0.8757696273654054, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.1s
# [CV] END estimator__C=0.8757696273654054, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=9.708388829209598, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=0.8757696273654054, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=9.708388829209598, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.4s
# [CV] END estimator__C=9.708388829209598, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.5s
# [CV] END estimator__C=0.8757696273654054, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=9.708388829209598, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=0.02324155736531398, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.5s
# [CV] END estimator__C=0.02324155736531398, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=0.02324155736531398, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.6s
# [CV] END estimator__C=9.708388829209598, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.5s
# [CV] END estimator__C=0.02324155736531398, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=0.02324155736531398, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.009881265006966004, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.3s
# [CV] END estimator__C=0.009881265006966004, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=0.009881265006966004, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=0.009881265006966004, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=1.4929341616866825, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.3s
# [CV] END estimator__C=1.4929341616866825, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.2s
# [CV] END estimator__C=1.4929341616866825, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.8s
# [CV] END estimator__C=10.918618008859, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=10.918618008859, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.0s
# [CV] END estimator__C=1.4929341616866825, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.0s
# [CV] END estimator__C=1.4929341616866825, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.2s
# [CV] END estimator__C=10.918618008859, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.4s
# [CV] END estimator__C=0.009881265006966004, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.7s
# [CV] END estimator__C=10.918618008859, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.7s
# [CV] END estimator__C=10.918618008859, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.6s
# [CV] END estimator__C=140.19283641250908, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.2s
# [CV] END estimator__C=140.19283641250908, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=0.03355112135641072, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.1s
# [CV] END estimator__C=0.03355112135641072, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=140.19283641250908, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.1s
# [CV] END estimator__C=0.16165419256540411, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.5s
# [CV] END estimator__C=0.03355112135641072, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.5s
# [CV] END estimator__C=0.16165419256540411, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.5s
# [CV] END estimator__C=0.03355112135641072, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=0.16165419256540411, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.6s
# [CV] END estimator__C=140.19283641250908, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.4s
# [CV] END estimator__C=0.03355112135641072, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.2s
# [CV] END estimator__C=62.573243884048885, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=62.573243884048885, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.6s
# [CV] END estimator__C=62.573243884048885, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.4s
# [CV] END estimator__C=9.382764277596852, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.9s
# [CV] END estimator__C=0.16165419256540411, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.6s
# [CV] END estimator__C=140.19283641250908, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.4s
# [CV] END estimator__C=62.573243884048885, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.1s
# [CV] END estimator__C=62.573243884048885, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.6s
# [CV] END estimator__C=0.16165419256540411, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=9.382764277596852, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.1s
# [CV] END estimator__C=9.382764277596852, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=161.18036211793935, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.3s
# [CV] END estimator__C=9.382764277596852, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.2s
# [CV] END estimator__C=161.18036211793935, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.4s
# [CV] END estimator__C=9.382764277596852, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.0s
# [CV] END estimator__C=161.18036211793935, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.9s
# [CV] END estimator__C=7.049799048651899, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.3s
# [CV] END estimator__C=7.049799048651899, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.6s
# [CV] END estimator__C=7.049799048651899, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.3s
# [CV] END estimator__C=161.18036211793935, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.2s
# [CV] END estimator__C=7.049799048651899, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=7.049799048651899, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.6s
# [CV] END estimator__C=84.32557507674147, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.5s
# [CV] END estimator__C=161.18036211793935, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.4s
# [CV] END estimator__C=84.32557507674147, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.3s
# [CV] END estimator__C=1.5236919507848834, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.5s[CV] END estimator__C=1.5236919507848834, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.6s
#
# [CV] END estimator__C=1.5236919507848834, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=84.32557507674147, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.1s[CV] END estimator__C=84.32557507674147, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.0s
#
# [CV] END estimator__C=1.5236919507848834, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=1.5236919507848834, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.0s
# [CV] END estimator__C=84.32557507674147, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.4s
# [CV] END estimator__C=2.687256036327758, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=2.687256036327758, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.5s
# [CV] END estimator__C=2.687256036327758, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=2.687256036327758, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=2.687256036327758, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=1.3801697855688684, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.0s
# [CV] END estimator__C=1.3801697855688684, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.8s
# [CV] END estimator__C=1.3801697855688684, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=1.3801697855688684, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.4s
# [CV] END estimator__C=1.3801697855688684, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.8s
# [CV] END estimator__C=896.7395120153604, estimator__gamma=scale, estimator__kernel=rbf; total time=   3.5s
# [CV] END estimator__C=0.45868362077943825, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=0.45868362077943825, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.5s
# [CV] END estimator__C=0.45868362077943825, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.3s
# [CV] END estimator__C=896.7395120153604, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.2s
# [CV] END estimator__C=0.45868362077943825, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.2s
# [CV] END estimator__C=205.7598403870436, estimator__gamma=scale, estimator__kernel=rbf; total time=   3.5s
# [CV] END estimator__C=88.26412125479264, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.5s
# [CV] END estimator__C=0.45868362077943825, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=88.26412125479264, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.7s
# [CV] END estimator__C=896.7395120153604, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.5s
# [CV] END estimator__C=88.26412125479264, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.9s
# [CV] END estimator__C=205.7598403870436, estimator__gamma=scale, estimator__kernel=rbf; total time=   3.5s
# [CV] END estimator__C=896.7395120153604, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=205.7598403870436, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.8s
# [CV] END estimator__C=205.7598403870436, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.2s
# [CV] END estimator__C=896.7395120153604, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.4s
# [CV] END estimator__C=88.26412125479264, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=205.7598403870436, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.4s
# [CV] END estimator__C=88.26412125479264, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.6s
# [CV] END estimator__C=20.80868303063541, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=20.80868303063541, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.3s
# [CV] END estimator__C=20.80868303063541, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.1s
# [CV] END estimator__C=20.80868303063541, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.1s
# [CV] END estimator__C=0.002447054846676343, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.3s
# [CV] END estimator__C=83.24296120321588, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.9s
# [CV] END estimator__C=20.80868303063541, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=0.002447054846676343, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.2s
# [CV] END estimator__C=20.181494083978755, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=20.181494083978755, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=83.24296120321588, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.4s
# [CV] END estimator__C=0.002447054846676343, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.5s
# [CV] END estimator__C=20.181494083978755, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=20.181494083978755, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=83.24296120321588, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=83.24296120321588, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=0.002447054846676343, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=20.181494083978755, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.8s
# [CV] END estimator__C=83.24296120321588, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.4s
# [CV] END estimator__C=0.002447054846676343, estimator__gamma=scale, estimator__kernel=rbf; total time=   9.2s
# [CV] END estimator__C=470.25978301273335, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.4s
# [CV] END estimator__C=470.25978301273335, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.8s
# [CV] END estimator__C=470.25978301273335, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.6s
# [CV] END estimator__C=310.3724909429448, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.5s
# [CV] END estimator__C=0.002364097415741704, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=310.3724909429448, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.4s
# [CV] END estimator__C=0.002364097415741704, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.3s
# [CV] END estimator__C=310.3724909429448, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.7s
# [CV] END estimator__C=0.002364097415741704, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.2s
# [CV] END estimator__C=470.25978301273335, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.1s
# [CV] END estimator__C=0.002364097415741704, estimator__gamma=auto, estimator__kernel=rbf; total time=   9.2s
# [CV] END estimator__C=310.3724909429448, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.4s
# [CV] END estimator__C=470.25978301273335, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=0.002364097415741704, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=0.002099207354246343, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=310.3724909429448, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=0.002099207354246343, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=0.002099207354246343, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.002099207354246343, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=51.77409079559643, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.5s
# [CV] END estimator__C=51.77409079559643, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.9s
# [CV] END estimator__C=0.002099207354246343, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.4s
# [CV] END estimator__C=51.77409079559643, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=51.77409079559643, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=0.08890712316352299, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=51.77409079559643, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=0.08890712316352299, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.4s
# [CV] END estimator__C=0.08890712316352299, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.6s
# [CV] END estimator__C=0.08890712316352299, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=0.08890712316352299, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.1s
# [CV] END estimator__C=0.025158549813580282, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.5s
# [CV] END estimator__C=0.025158549813580282, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.0s
# [CV] END estimator__C=0.025158549813580282, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.5s
# [CV] END estimator__C=0.025158549813580282, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.3s
# [CV] END estimator__C=0.025158549813580282, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.8s
# [CV] END estimator__C=0.02946657449213803, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=0.02946657449213803, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=0.02946657449213803, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.5s
# [CV] END estimator__C=0.02946657449213803, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.4s
# [CV] END estimator__C=0.02946657449213803, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.8s
# [CV] END estimator__C=0.001268406649981021, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=0.001268406649981021, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.8s
# [CV] END estimator__C=0.001268406649981021, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.5s
# [CV] END estimator__C=0.001268406649981021, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.7s
# [CV] END estimator__C=0.3806182594041696, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.8s
# [CV] END estimator__C=0.3806182594041696, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.9s
# [CV] END estimator__C=0.001268406649981021, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.6s
# [CV] END estimator__C=0.3806182594041696, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.0s
# [CV] END estimator__C=0.3806182594041696, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.7s
# [CV] END estimator__C=0.3806182594041696, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.8s
# [CV] END estimator__C=0.005592384783271568, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.0s
# [CV] END estimator__C=84.1746445046142, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=0.005592384783271568, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.9s
# [CV] END estimator__C=0.005592384783271568, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.9s
# [CV] END estimator__C=84.1746445046142, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.7s
# [CV] END estimator__C=84.1746445046142, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.5s
# [CV] END estimator__C=84.1746445046142, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=0.005592384783271568, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.7s
# [CV] END estimator__C=84.1746445046142, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.3s
# [CV] END estimator__C=0.5506754833745539, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=0.5506754833745539, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=0.5506754833745539, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=0.005592384783271568, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=0.5506754833745539, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.1s
# [CV] END estimator__C=109.34809669350199, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.6s
# [CV] END estimator__C=0.5506754833745539, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.5s
# [CV] END estimator__C=109.34809669350199, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.9s
# [CV] END estimator__C=109.34809669350199, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.0s
# [CV] END estimator__C=109.34809669350199, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.8s
# [CV] END estimator__C=109.34809669350199, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.8s
# [CV] END estimator__C=0.003771883089321664, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=0.003771883089321664, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.003771883089321664, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.6s
# [CV] END estimator__C=0.003771883089321664, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=399.19111365985526, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=35.101986325377275, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.7s
# [CV] END estimator__C=0.003771883089321664, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=35.101986325377275, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=399.19111365985526, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.5s
# [CV] END estimator__C=35.101986325377275, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=35.101986325377275, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=399.19111365985526, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=399.19111365985526, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.9s
# [CV] END estimator__C=0.00849787016809765, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=35.101986325377275, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=0.00849787016809765, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=399.19111365985526, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.9s
# [CV] END estimator__C=0.00849787016809765, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=0.00849787016809765, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.5s
# [CV] END estimator__C=0.00849787016809765, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=0.004840418440633975, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.5s
# [CV] END estimator__C=0.004840418440633975, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.7s
# [CV] END estimator__C=0.004840418440633975, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.9s
# [CV] END estimator__C=0.004840418440633975, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.4s
# [CV] END estimator__C=0.004840418440633975, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=6.834678760315267, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.2s
# [CV] END estimator__C=3.6351436173462606, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.5s
# [CV] END estimator__C=6.834678760315267, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.6s
# [CV] END estimator__C=3.6351436173462606, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=3.6351436173462606, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.0s
# [CV] END estimator__C=0.04595063497965719, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.8s
# [CV] END estimator__C=3.6351436173462606, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.9s
# [CV] END estimator__C=0.04595063497965719, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.5s
# [CV] END estimator__C=0.04595063497965719, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=0.001997903492402694, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=3.6351436173462606, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=0.04595063497965719, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.9s
# [CV] END estimator__C=0.04595063497965719, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.2s
# [CV] END estimator__C=6.834678760315267, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.9s
# [CV] END estimator__C=0.001997903492402694, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=0.001997903492402694, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=6.834678760315267, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.7s
# [CV] END estimator__C=0.001997903492402694, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.5s
# [CV] END estimator__C=6.834678760315267, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=0.001997903492402694, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=355.57646457062805, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.5s
# [CV] END estimator__C=355.57646457062805, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.6s
# [CV] END estimator__C=355.57646457062805, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.8s
# [CV] END estimator__C=355.57646457062805, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.4s
# [CV] END estimator__C=355.57646457062805, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=0.042956516853752534, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=19.120408124086985, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.1s
# [CV] END estimator__C=19.120408124086985, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=0.042956516853752534, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=19.120408124086985, estimator__gamma=scale, estimator__kernel=rbf; total time=   3.8s
# ...
# [CV] END estimator__C=0.001550847347894364, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=0.001550847347894364, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=580.7809800175964, estimator__gamma=scale, estimator__kernel=rbf; total time=   3.5s
# [CV] END estimator__C=0.001550847347894364, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.5s
# [CV] END estimator__C=580.7809800175964, estimator__gamma=scale, estimator__kernel=rbf; total time=   3.9s
# [CV] END estimator__C=580.7809800175964, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=0.0968558456377908, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.2s
# [CV] END estimator__C=0.0968558456377908, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=580.7809800175964, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=0.0968558456377908, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=0.002972808945175863, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.3s
# [CV] END estimator__C=580.7809800175964, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.5s
# [CV] END estimator__C=0.0968558456377908, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=0.0968558456377908, estimator__gamma=scale, estimator__kernel=rbf; total time=   9.1s
# [CV] END estimator__C=0.002972808945175863, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.3s
# [CV] END estimator__C=0.002972808945175863, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.002972808945175863, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.6s
# [CV] END estimator__C=0.002972808945175863, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.5s
# [CV] END estimator__C=2.872638545197199, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.2s
# [CV] END estimator__C=0.017174166025347853, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=2.872638545197199, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.8s
# [CV] END estimator__C=0.017174166025347853, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=2.872638545197199, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.8s
# [CV] END estimator__C=2.872638545197199, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.0s
# [CV] END estimator__C=0.017174166025347853, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.6s
# [CV] END estimator__C=0.017174166025347853, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.5s
# [CV] END estimator__C=2.872638545197199, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=1.483161945951551, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.8s
# [CV] END estimator__C=1.483161945951551, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=1.483161945951551, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.0s
# [CV] END estimator__C=0.017174166025347853, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=1.483161945951551, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=1.483161945951551, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.8s
# [CV] END estimator__C=0.016036113554734825, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=0.016036113554734825, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=0.016036113554734825, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=0.016036113554734825, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.016036113554734825, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.5s
# [CV] END estimator__C=0.003863543098443557, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.003863543098443557, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=0.003863543098443557, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.1s
# [CV] END estimator__C=0.003863543098443557, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.1s
# [CV] END estimator__C=164.9199478096019, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.0s
# [CV] END estimator__C=164.9199478096019, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=0.003863543098443557, estimator__gamma=auto, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=0.10301863580064671, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=164.9199478096019, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.5s
# [CV] END estimator__C=164.9199478096019, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=0.10301863580064671, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.1s
# [CV] END estimator__C=164.9199478096019, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.0s
# [CV] END estimator__C=0.10301863580064671, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.7s
# [CV] END estimator__C=0.10301863580064671, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.8s
# [CV] END estimator__C=0.10301863580064671, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.8s
# [CV] END estimator__C=333.9419800209255, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.4s
# [CV] END estimator__C=68.54111519408127, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.4s
# [CV] END estimator__C=333.9419800209255, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.2s
# [CV] END estimator__C=333.9419800209255, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.1s
# [CV] END estimator__C=68.54111519408127, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=68.54111519408127, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.3s
# [CV] END estimator__C=68.54111519408127, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.9s
# [CV] END estimator__C=0.1280480311397158, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.9s
# [CV] END estimator__C=0.1280480311397158, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.6s
# [CV] END estimator__C=333.9419800209255, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=0.1280480311397158, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.8s
# [CV] END estimator__C=68.54111519408127, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.6s
# [CV] END estimator__C=0.1280480311397158, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.2s
# [CV] END estimator__C=333.9419800209255, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.4s
# [CV] END estimator__C=0.1280480311397158, estimator__gamma=scale, estimator__kernel=rbf; total time=   9.0s
# [CV] END estimator__C=242.59006120524586, estimator__gamma=scale, estimator__kernel=rbf; total time=   3.7s
# [CV] END estimator__C=242.59006120524586, estimator__gamma=scale, estimator__kernel=rbf; total time=   3.5s
# [CV] END estimator__C=242.59006120524586, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=242.59006120524586, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=21.033144743875354, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.2s
# [CV] END estimator__C=242.59006120524586, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.3s
# [CV] END estimator__C=21.033144743875354, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.9s
# [CV] END estimator__C=19.799273153181982, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.7s
# [CV] END estimator__C=19.799273153181982, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.8s
# [CV] END estimator__C=21.033144743875354, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.6s
# [CV] END estimator__C=21.033144743875354, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.0s
# [CV] END estimator__C=19.799273153181982, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.3s
# [CV] END estimator__C=21.033144743875354, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=2.44406211552462, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.1s
# [CV] END estimator__C=2.44406211552462, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.2s
# [CV] END estimator__C=2.44406211552462, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.5s
# [CV] END estimator__C=19.799273153181982, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=2.44406211552462, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.9s
# [CV] END estimator__C=2.44406211552462, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=19.799273153181982, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.6s
# [CV] END estimator__C=670.2386051527723, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=670.2386051527723, estimator__gamma=scale, estimator__kernel=rbf; total time=   4.7s
# [CV] END estimator__C=670.2386051527723, estimator__gamma=scale, estimator__kernel=rbf; total time=   5.2s
# [CV] END estimator__C=670.2386051527723, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.0s
# [CV] END estimator__C=1.421572176229016, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=1.421572176229016, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.6s
# [CV] END estimator__C=18.817636934596198, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.8s
# [CV] END estimator__C=1.421572176229016, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.9s
# [CV] END estimator__C=670.2386051527723, estimator__gamma=scale, estimator__kernel=rbf; total time=   6.2s
# [CV] END estimator__C=18.817636934596198, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.9s
# [CV] END estimator__C=749.4068418023791, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.6s
# [CV] END estimator__C=1.421572176229016, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.6s
# [CV] END estimator__C=1.421572176229016, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.0s
# [CV] END estimator__C=749.4068418023791, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.9s
# [CV] END estimator__C=18.817636934596198, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.1s
# [CV] END estimator__C=18.817636934596198, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.4s
# [CV] END estimator__C=749.4068418023791, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.5s
# [CV] END estimator__C=749.4068418023791, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.7s
# [CV] END estimator__C=18.817636934596198, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.1s
# [CV] END estimator__C=749.4068418023791, estimator__gamma=auto, estimator__kernel=rbf; total time=   4.2s
# [CV] END estimator__C=0.0038159920132605904, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.6s
# [CV] END estimator__C=0.0038159920132605904, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.9s
# [CV] END estimator__C=0.0038159920132605904, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.8s
# [CV] END estimator__C=0.0038159920132605904, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.4s
# [CV] END estimator__C=0.0038159920132605904, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.3s
# [CV] END estimator__C=1.5799404224664575, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.3s
# [CV] END estimator__C=1.5799404224664575, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.1s
# [CV] END estimator__C=1.5799404224664575, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.4s
# [CV] END estimator__C=1.5799404224664575, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.7s
# [CV] END estimator__C=1.5799404224664575, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.8s
# [CV] END estimator__C=507.0333848815856, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.7s
# [CV] END estimator__C=507.0333848815856, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.7s
# [CV] END estimator__C=507.0333848815856, estimator__gamma=auto, estimator__kernel=rbf; total time=   3.9s
# [CV] END estimator__C=0.014164815843877607, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.8s
# [CV] END estimator__C=0.014164815843877607, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.1s
# [CV] END estimator__C=0.014164815843877607, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.1s
# [CV] END estimator__C=0.014164815843877607, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=0.006397752492464969, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.1s
# [CV] END estimator__C=0.03543141878523273, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.2s
# [CV] END estimator__C=0.014164815843877607, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=507.0333848815856, estimator__gamma=auto, estimator__kernel=rbf; total time=   5.1s
# [CV] END estimator__C=0.006397752492464969, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=0.006397752492464969, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.4s
# [CV] END estimator__C=0.006397752492464969, estimator__gamma=scale, estimator__kernel=rbf; total time=   8.3s
# [CV] END estimator__C=0.006397752492464969, estimator__gamma=scale, estimator__kernel=rbf; total time=   7.9s
# [CV] END estimator__C=0.03543141878523273, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.6s
# [CV] END estimator__C=0.03543141878523273, estimator__gamma=auto, estimator__kernel=rbf; total time=   7.7s
# [CV] END estimator__C=0.03543141878523273, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.1s
# [CV] END estimator__C=0.03543141878523273, estimator__gamma=auto, estimator__kernel=rbf; total time=   6.4s
# [CV] END estimator__C=507.0333848815856, estimator__gamma=auto, estimator__kernel=rbf; total time=   2.7s
# RandomizedSearchCV(cv=[(array([ 639,  640,  641, ..., 9588, 9589, 9590], shape=(3518,)),
#                         array([1598, 1599, 1600, ..., 8310, 8311, 8312], shape=(1917,))),
#                        (array([ 639,  640,  641, ..., 9588, 9589, 9590], shape=(3518,)),
#                         array([1598, 1599, 1600, ..., 7990, 7991, 7992], shape=(1917,))),
#                        (array([ 639,  640,  641, ..., 9588, 9589, 9590], shape=(3518,)),
#                         array([ 959,  960,  961, ..., 7990, 7991, 7992], shape=(...
#                         array([ 639,  640,  641, ..., 7990, 7991, 7992], shape=(1918,)))],
#                    estimator=MultiOutputClassifier(estimator=SVC(probability=True)),
#                    n_iter=250, n_jobs=-1,
#                    param_distributions={'estimator__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f1b8bfd5d90>,
#                                         'estimator__gamma': ['scale', 'auto'],
#                                         'estimator__kernel': ['rbf']},
#                    scoring='roc_auc', verbose=2)

# %%
results = pd.DataFrame(random_search.cv_results_).sort_values(by="rank_test_score")

# %%
results.iloc[0]
# Out:
# mean_fit_time                                                       4.731125
# std_fit_time                                                         0.68196
# mean_score_time                                                     0.444534
# std_score_time                                                      0.085182
# param_estimator__C                                                 73.823576
# param_estimator__gamma                                                 scale
# param_estimator__kernel                                                  rbf
# params                     {'estimator__C': 73.8235760253899, 'estimator_...
# split0_test_score                                                   0.855259
# split1_test_score                                                   0.685216
# split2_test_score                                                   0.545223
# split3_test_score                                                   0.503153
# split4_test_score                                                    0.70019
# mean_test_score                                                     0.657808
# std_test_score                                                      0.125002
# rank_test_score                                                            1
# Name: 2, dtype: object

# %%
best_params = results.iloc[0]["params"]

# %%
best_params.values()
# Out:
# dict_values([np.float64(73.8235760253899), 'scale', 'rbf'])

# %%
keys = []
for i in best_params.keys():
    keys.append(i.replace("estimator__", ""))

# %%
best_params = {k: i for (k,i) in zip(keys, best_params.values())}

# %%
best_params
# Out:
# {'C': np.float64(73.8235760253899), 'gamma': 'scale', 'kernel': 'rbf'}

# %%
from sklearn.metrics import roc_auc_score

#### WITHOUT COMBINEDS
cvs = [get_cv_splits(sampler=sampler, df=df, run=run,
 healthy_bearing_ids=healthy_bearing_ids, outer_bearing_ids=outer_bearing_ids,
  inner_bearing_ids=inner_bearing_ids, use_combined=False, on_train=False)
 for run in range(5,105)]

aucs = []
for cv in cvs:

    X_train = X.iloc[cv[0]]
    X_test = X.iloc[cv[1]]

    y_train = y.iloc[cv[0]]
    y_test = y.iloc[cv[1]]

    model = MultiOutputClassifier(SVC(random_state=42, **best_params, probability=True), n_jobs=-1)

    model.fit(X_train, y_train)
    y_probas = model.predict_proba(X_test)
    proba_outer = y_probas[1][:, 1]
    proba_inner = y_probas[0][:, 1]

    auroc_outer = roc_auc_score(y_test["outer"], proba_outer)
    auroc_inner = roc_auc_score(y_test["inner"], proba_inner)

    macro_auc = np.mean([auroc_outer, auroc_inner])
    print(f"Macro AUC: {macro_auc:.4f} | Outer AUC: {auroc_outer:.4f} | Inner AUC: {auroc_inner:.4f}")
    aucs.append([macro_auc, auroc_outer, auroc_inner])
# Out:
# Macro AUC: 0.5727 | Outer AUC: 0.7267 | Inner AUC: 0.4187
# Macro AUC: 0.5464 | Outer AUC: 0.7860 | Inner AUC: 0.3068
# Macro AUC: 0.2722 | Outer AUC: 0.3988 | Inner AUC: 0.1455
# Macro AUC: 0.5850 | Outer AUC: 0.6949 | Inner AUC: 0.4752
# Macro AUC: 0.5517 | Outer AUC: 0.5967 | Inner AUC: 0.5067
# Macro AUC: 0.4587 | Outer AUC: 0.7118 | Inner AUC: 0.2057
# Macro AUC: 0.3553 | Outer AUC: 0.4352 | Inner AUC: 0.2754
# Macro AUC: 0.3440 | Outer AUC: 0.3594 | Inner AUC: 0.3286
# Macro AUC: 0.7099 | Outer AUC: 0.8150 | Inner AUC: 0.6049
# Macro AUC: 0.9022 | Outer AUC: 0.8654 | Inner AUC: 0.9389
# Macro AUC: 0.6048 | Outer AUC: 0.5822 | Inner AUC: 0.6273
# Macro AUC: 0.4801 | Outer AUC: 0.3592 | Inner AUC: 0.6009
# Macro AUC: 0.5613 | Outer AUC: 0.6539 | Inner AUC: 0.4688
# Macro AUC: 0.6462 | Outer AUC: 0.8493 | Inner AUC: 0.4430
# Macro AUC: 0.8653 | Outer AUC: 0.8942 | Inner AUC: 0.8363
# Macro AUC: 0.8112 | Outer AUC: 0.8237 | Inner AUC: 0.7987
# Macro AUC: 0.6335 | Outer AUC: 0.8750 | Inner AUC: 0.3919
# Macro AUC: 0.3068 | Outer AUC: 0.5651 | Inner AUC: 0.0486
# Macro AUC: 0.6447 | Outer AUC: 0.8391 | Inner AUC: 0.4503
# Macro AUC: 0.8086 | Outer AUC: 0.8683 | Inner AUC: 0.7489
# Macro AUC: 0.5885 | Outer AUC: 0.6053 | Inner AUC: 0.5716
# Macro AUC: 0.6029 | Outer AUC: 0.8755 | Inner AUC: 0.3303
# Macro AUC: 0.5238 | Outer AUC: 0.7102 | Inner AUC: 0.3375
# Macro AUC: 0.7531 | Outer AUC: 0.7626 | Inner AUC: 0.7435
# Macro AUC: 0.3946 | Outer AUC: 0.5724 | Inner AUC: 0.2169
# Macro AUC: 0.7131 | Outer AUC: 0.6941 | Inner AUC: 0.7320
# Macro AUC: 0.7938 | Outer AUC: 0.7738 | Inner AUC: 0.8139
# Macro AUC: 0.6516 | Outer AUC: 0.8464 | Inner AUC: 0.4569
# Macro AUC: 0.4017 | Outer AUC: 0.3050 | Inner AUC: 0.4983
# Macro AUC: 0.6281 | Outer AUC: 0.7034 | Inner AUC: 0.5528
# Macro AUC: 0.4335 | Outer AUC: 0.7509 | Inner AUC: 0.1160
# Macro AUC: 0.7945 | Outer AUC: 0.8624 | Inner AUC: 0.7266
# Macro AUC: 0.6837 | Outer AUC: 0.6376 | Inner AUC: 0.7297
# Macro AUC: 0.4656 | Outer AUC: 0.6375 | Inner AUC: 0.2938
# Macro AUC: 0.6270 | Outer AUC: 0.7856 | Inner AUC: 0.4685
# Macro AUC: 0.5817 | Outer AUC: 0.8616 | Inner AUC: 0.3017
# Macro AUC: 0.8365 | Outer AUC: 0.8053 | Inner AUC: 0.8678
# Macro AUC: 0.3500 | Outer AUC: 0.3187 | Inner AUC: 0.3814
# Macro AUC: 0.7306 | Outer AUC: 0.8298 | Inner AUC: 0.6315
# Macro AUC: 0.4684 | Outer AUC: 0.6349 | Inner AUC: 0.3020
# Macro AUC: 0.5538 | Outer AUC: 0.7642 | Inner AUC: 0.3434
# Macro AUC: 0.6547 | Outer AUC: 0.8240 | Inner AUC: 0.4853
# Macro AUC: 0.4029 | Outer AUC: 0.5705 | Inner AUC: 0.2353
# Macro AUC: 0.3795 | Outer AUC: 0.2663 | Inner AUC: 0.4927
# Macro AUC: 0.6175 | Outer AUC: 0.7166 | Inner AUC: 0.5184
# Macro AUC: 0.7394 | Outer AUC: 0.6798 | Inner AUC: 0.7991
# Macro AUC: 0.5757 | Outer AUC: 0.7494 | Inner AUC: 0.4020
# Macro AUC: 0.6741 | Outer AUC: 0.7134 | Inner AUC: 0.6348
# Macro AUC: 0.3560 | Outer AUC: 0.1848 | Inner AUC: 0.5271
# Macro AUC: 0.7067 | Outer AUC: 0.7286 | Inner AUC: 0.6847
# Macro AUC: 0.7303 | Outer AUC: 0.7480 | Inner AUC: 0.7126
# Macro AUC: 0.2488 | Outer AUC: 0.3066 | Inner AUC: 0.1910
# Macro AUC: 0.5796 | Outer AUC: 0.8587 | Inner AUC: 0.3004
# Macro AUC: 0.5021 | Outer AUC: 0.6804 | Inner AUC: 0.3238
# Macro AUC: 0.8858 | Outer AUC: 0.8924 | Inner AUC: 0.8792
# Macro AUC: 0.7852 | Outer AUC: 0.7674 | Inner AUC: 0.8030
# Macro AUC: 0.4753 | Outer AUC: 0.7739 | Inner AUC: 0.1768
# Macro AUC: 0.4528 | Outer AUC: 0.3774 | Inner AUC: 0.5282
# Macro AUC: 0.2605 | Outer AUC: 0.4099 | Inner AUC: 0.1112
# Macro AUC: 0.4434 | Outer AUC: 0.7679 | Inner AUC: 0.1189
# Macro AUC: 0.1998 | Outer AUC: 0.1926 | Inner AUC: 0.2070
# Macro AUC: 0.6350 | Outer AUC: 0.5144 | Inner AUC: 0.7556
# Macro AUC: 0.4571 | Outer AUC: 0.5263 | Inner AUC: 0.3879
# Macro AUC: 0.9105 | Outer AUC: 0.8665 | Inner AUC: 0.9546
# Macro AUC: 0.5478 | Outer AUC: 0.5374 | Inner AUC: 0.5582
# Macro AUC: 0.5254 | Outer AUC: 0.5237 | Inner AUC: 0.5270
# Macro AUC: 0.7180 | Outer AUC: 0.7805 | Inner AUC: 0.6556
# Macro AUC: 0.2858 | Outer AUC: 0.1867 | Inner AUC: 0.3850
# Macro AUC: 0.4995 | Outer AUC: 0.4981 | Inner AUC: 0.5009
# Macro AUC: 0.2279 | Outer AUC: 0.3677 | Inner AUC: 0.0882
# Macro AUC: 0.3959 | Outer AUC: 0.0733 | Inner AUC: 0.7186
# Macro AUC: 0.4258 | Outer AUC: 0.5887 | Inner AUC: 0.2629
# Macro AUC: 0.1592 | Outer AUC: 0.0987 | Inner AUC: 0.2197
# Macro AUC: 0.6763 | Outer AUC: 0.7269 | Inner AUC: 0.6256
# Macro AUC: 0.3217 | Outer AUC: 0.2702 | Inner AUC: 0.3732
# Macro AUC: 0.5028 | Outer AUC: 0.7684 | Inner AUC: 0.2372
# Macro AUC: 0.2670 | Outer AUC: 0.1806 | Inner AUC: 0.3534
# Macro AUC: 0.4782 | Outer AUC: 0.6009 | Inner AUC: 0.3555
# Macro AUC: 0.5679 | Outer AUC: 0.6112 | Inner AUC: 0.5247
# Macro AUC: 0.4920 | Outer AUC: 0.6250 | Inner AUC: 0.3590
# Macro AUC: 0.7760 | Outer AUC: 0.7148 | Inner AUC: 0.8371
# Macro AUC: 0.4234 | Outer AUC: 0.6701 | Inner AUC: 0.1768
# Macro AUC: 0.6502 | Outer AUC: 0.8653 | Inner AUC: 0.4351
# Macro AUC: 0.1840 | Outer AUC: 0.1754 | Inner AUC: 0.1925
# Macro AUC: 0.5570 | Outer AUC: 0.7446 | Inner AUC: 0.3694
# Macro AUC: 0.7864 | Outer AUC: 0.8071 | Inner AUC: 0.7657
# Macro AUC: 0.5040 | Outer AUC: 0.5593 | Inner AUC: 0.4486
# Macro AUC: 0.2795 | Outer AUC: 0.3509 | Inner AUC: 0.2081
# Macro AUC: 0.5591 | Outer AUC: 0.3301 | Inner AUC: 0.7881
# Macro AUC: 0.6139 | Outer AUC: 0.8083 | Inner AUC: 0.4194
# Macro AUC: 0.8051 | Outer AUC: 0.9100 | Inner AUC: 0.7002
# Macro AUC: 0.4758 | Outer AUC: 0.6114 | Inner AUC: 0.3403
# Macro AUC: 0.6108 | Outer AUC: 0.7126 | Inner AUC: 0.5091
# Macro AUC: 0.6276 | Outer AUC: 0.7948 | Inner AUC: 0.4603
# Macro AUC: 0.4278 | Outer AUC: 0.6967 | Inner AUC: 0.1589
# Macro AUC: 0.6730 | Outer AUC: 0.6961 | Inner AUC: 0.6499
# Macro AUC: 0.7237 | Outer AUC: 0.7209 | Inner AUC: 0.7266
# Macro AUC: 0.5830 | Outer AUC: 0.7578 | Inner AUC: 0.4082
# Macro AUC: 0.7906 | Outer AUC: 0.6701 | Inner AUC: 0.9110
# Macro AUC: 0.5919 | Outer AUC: 0.5849 | Inner AUC: 0.5988

# %%
macro_aucs = [i[0] for i in aucs]
np.mean(macro_aucs), np.std(macro_aucs)
# Out:
# (np.float64(0.5564388467419942), np.float64(0.17488943549310645))

# %%
from sklearn.metrics import roc_auc_score

#### WITH COMBINEDS
cvs = [get_cv_splits(sampler=sampler, df=df, run=run,
 healthy_bearing_ids=healthy_bearing_ids, outer_bearing_ids=outer_bearing_ids,
  inner_bearing_ids=inner_bearing_ids, use_combined=True, on_train=False)
 for run in range(5,105)]

aucs = []
for cv in cvs:

    X_train = X.iloc[cv[0]]
    X_test = X.iloc[cv[1]]

    y_train = y.iloc[cv[0]]
    y_test = y.iloc[cv[1]]

    model = MultiOutputClassifier(SVC(random_state=42, **best_params, probability=True), n_jobs=-1)

    model.fit(X_train, y_train)
    y_probas = model.predict_proba(X_test)
    proba_outer = y_probas[1][:, 1]
    proba_inner = y_probas[0][:, 1]

    auroc_outer = roc_auc_score(y_test["outer"], proba_outer)
    auroc_inner = roc_auc_score(y_test["inner"], proba_inner)

    macro_auc = np.mean([auroc_outer, auroc_inner])
    print(f"Macro AUC: {macro_auc:.4f} | Outer AUC: {auroc_outer:.4f} | Inner AUC: {auroc_inner:.4f}")
    aucs.append([macro_auc, auroc_outer, auroc_inner])
# Out:
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Using combined bearings on test: ['KB23', 'KB24', 'KB27']
# Macro AUC: 0.5245 | Outer AUC: 0.5100 | Inner AUC: 0.5391
# Macro AUC: 0.4205 | Outer AUC: 0.5980 | Inner AUC: 0.2430
# Macro AUC: 0.3911 | Outer AUC: 0.6019 | Inner AUC: 0.1804
# Macro AUC: 0.5145 | Outer AUC: 0.5684 | Inner AUC: 0.4606
# Macro AUC: 0.5591 | Outer AUC: 0.5046 | Inner AUC: 0.6137
# Macro AUC: 0.3763 | Outer AUC: 0.5136 | Inner AUC: 0.2391
# Macro AUC: 0.4522 | Outer AUC: 0.4066 | Inner AUC: 0.4978
# Macro AUC: 0.4164 | Outer AUC: 0.3689 | Inner AUC: 0.4640
# Macro AUC: 0.5378 | Outer AUC: 0.6287 | Inner AUC: 0.4470
# Macro AUC: 0.8318 | Outer AUC: 0.8096 | Inner AUC: 0.8541
# Macro AUC: 0.6642 | Outer AUC: 0.6294 | Inner AUC: 0.6989
# Macro AUC: 0.4993 | Outer AUC: 0.3537 | Inner AUC: 0.6448
# Macro AUC: 0.4928 | Outer AUC: 0.6559 | Inner AUC: 0.3298
# Macro AUC: 0.4437 | Outer AUC: 0.5524 | Inner AUC: 0.3351
# Macro AUC: 0.6939 | Outer AUC: 0.7075 | Inner AUC: 0.6802
# Macro AUC: 0.7599 | Outer AUC: 0.7961 | Inner AUC: 0.7237
# Macro AUC: 0.5530 | Outer AUC: 0.5658 | Inner AUC: 0.5402
# Macro AUC: 0.4110 | Outer AUC: 0.4657 | Inner AUC: 0.3562
# Macro AUC: 0.5593 | Outer AUC: 0.5736 | Inner AUC: 0.5450
# Macro AUC: 0.6932 | Outer AUC: 0.6048 | Inner AUC: 0.7817
# Macro AUC: 0.5391 | Outer AUC: 0.3876 | Inner AUC: 0.6905
# Macro AUC: 0.4856 | Outer AUC: 0.7367 | Inner AUC: 0.2346
# Macro AUC: 0.4365 | Outer AUC: 0.6162 | Inner AUC: 0.2567
# Macro AUC: 0.7470 | Outer AUC: 0.7269 | Inner AUC: 0.7671
# Macro AUC: 0.3197 | Outer AUC: 0.4275 | Inner AUC: 0.2118
# Macro AUC: 0.6668 | Outer AUC: 0.5931 | Inner AUC: 0.7405
# Macro AUC: 0.7584 | Outer AUC: 0.7470 | Inner AUC: 0.7697
# Macro AUC: 0.4549 | Outer AUC: 0.5579 | Inner AUC: 0.3518
# Macro AUC: 0.4551 | Outer AUC: 0.3762 | Inner AUC: 0.5340
# Macro AUC: 0.6377 | Outer AUC: 0.6423 | Inner AUC: 0.6332
# Macro AUC: 0.3881 | Outer AUC: 0.5877 | Inner AUC: 0.1885
# Macro AUC: 0.6849 | Outer AUC: 0.6506 | Inner AUC: 0.7191
# Macro AUC: 0.5940 | Outer AUC: 0.5293 | Inner AUC: 0.6587
# Macro AUC: 0.4530 | Outer AUC: 0.6783 | Inner AUC: 0.2277
# Macro AUC: 0.5643 | Outer AUC: 0.5222 | Inner AUC: 0.6064
# Macro AUC: 0.4884 | Outer AUC: 0.6863 | Inner AUC: 0.2906
# Macro AUC: 0.6599 | Outer AUC: 0.5238 | Inner AUC: 0.7961
# Macro AUC: 0.3821 | Outer AUC: 0.3490 | Inner AUC: 0.4153
# Macro AUC: 0.6647 | Outer AUC: 0.6081 | Inner AUC: 0.7212
# Macro AUC: 0.3622 | Outer AUC: 0.5104 | Inner AUC: 0.2140
# Macro AUC: 0.4220 | Outer AUC: 0.5418 | Inner AUC: 0.3022
# Macro AUC: 0.5596 | Outer AUC: 0.5383 | Inner AUC: 0.5808
# Macro AUC: 0.3862 | Outer AUC: 0.5050 | Inner AUC: 0.2674
# Macro AUC: 0.4138 | Outer AUC: 0.3597 | Inner AUC: 0.4679
# Macro AUC: 0.5158 | Outer AUC: 0.4332 | Inner AUC: 0.5984
# Macro AUC: 0.7360 | Outer AUC: 0.7125 | Inner AUC: 0.7595
# Macro AUC: 0.4451 | Outer AUC: 0.5329 | Inner AUC: 0.3573
# Macro AUC: 0.6225 | Outer AUC: 0.5385 | Inner AUC: 0.7065
# Macro AUC: 0.4426 | Outer AUC: 0.2882 | Inner AUC: 0.5970
# Macro AUC: 0.7070 | Outer AUC: 0.7122 | Inner AUC: 0.7018
# Macro AUC: 0.6018 | Outer AUC: 0.6407 | Inner AUC: 0.5629
# Macro AUC: 0.2931 | Outer AUC: 0.3544 | Inner AUC: 0.2318
# Macro AUC: 0.5575 | Outer AUC: 0.5947 | Inner AUC: 0.5202
# Macro AUC: 0.3959 | Outer AUC: 0.5676 | Inner AUC: 0.2242
# Macro AUC: 0.7040 | Outer AUC: 0.7078 | Inner AUC: 0.7001
# Macro AUC: 0.7465 | Outer AUC: 0.7015 | Inner AUC: 0.7915
# Macro AUC: 0.4399 | Outer AUC: 0.5665 | Inner AUC: 0.3134
# Macro AUC: 0.4751 | Outer AUC: 0.3572 | Inner AUC: 0.5930
# Macro AUC: 0.3623 | Outer AUC: 0.5339 | Inner AUC: 0.1907
# Macro AUC: 0.3899 | Outer AUC: 0.5944 | Inner AUC: 0.1853
# Macro AUC: 0.2081 | Outer AUC: 0.2274 | Inner AUC: 0.1889
# Macro AUC: 0.6367 | Outer AUC: 0.5336 | Inner AUC: 0.7397
# Macro AUC: 0.4289 | Outer AUC: 0.5732 | Inner AUC: 0.2846
# Macro AUC: 0.8591 | Outer AUC: 0.8334 | Inner AUC: 0.8848
# Macro AUC: 0.6148 | Outer AUC: 0.5674 | Inner AUC: 0.6622
# Macro AUC: 0.5594 | Outer AUC: 0.4770 | Inner AUC: 0.6419
# Macro AUC: 0.6721 | Outer AUC: 0.6376 | Inner AUC: 0.7065
# Macro AUC: 0.2768 | Outer AUC: 0.2751 | Inner AUC: 0.2786
# Macro AUC: 0.5181 | Outer AUC: 0.4371 | Inner AUC: 0.5990
# Macro AUC: 0.2538 | Outer AUC: 0.3589 | Inner AUC: 0.1487
# Macro AUC: 0.3897 | Outer AUC: 0.1281 | Inner AUC: 0.6513
# Macro AUC: 0.4245 | Outer AUC: 0.5554 | Inner AUC: 0.2936
# Macro AUC: 0.2750 | Outer AUC: 0.1708 | Inner AUC: 0.3791
# Macro AUC: 0.6215 | Outer AUC: 0.5441 | Inner AUC: 0.6989
# Macro AUC: 0.3703 | Outer AUC: 0.3030 | Inner AUC: 0.4375
# Macro AUC: 0.5114 | Outer AUC: 0.5346 | Inner AUC: 0.4883
# Macro AUC: 0.3395 | Outer AUC: 0.2072 | Inner AUC: 0.4719
# Macro AUC: 0.4675 | Outer AUC: 0.5123 | Inner AUC: 0.4227
# Macro AUC: 0.5821 | Outer AUC: 0.5036 | Inner AUC: 0.6605
# Macro AUC: 0.3906 | Outer AUC: 0.5159 | Inner AUC: 0.2653
# Macro AUC: 0.7753 | Outer AUC: 0.7598 | Inner AUC: 0.7909
# Macro AUC: 0.4130 | Outer AUC: 0.6293 | Inner AUC: 0.1967
# Macro AUC: 0.4618 | Outer AUC: 0.6260 | Inner AUC: 0.2975
# Macro AUC: 0.2023 | Outer AUC: 0.1865 | Inner AUC: 0.2182
# Macro AUC: 0.5118 | Outer AUC: 0.7219 | Inner AUC: 0.3017
# Macro AUC: 0.6890 | Outer AUC: 0.6845 | Inner AUC: 0.6935
# Macro AUC: 0.5469 | Outer AUC: 0.4831 | Inner AUC: 0.6106
# Macro AUC: 0.3800 | Outer AUC: 0.5660 | Inner AUC: 0.1940
# Macro AUC: 0.5714 | Outer AUC: 0.3960 | Inner AUC: 0.7468
# Macro AUC: 0.5826 | Outer AUC: 0.5516 | Inner AUC: 0.6135
# Macro AUC: 0.7206 | Outer AUC: 0.7068 | Inner AUC: 0.7344
# Macro AUC: 0.4507 | Outer AUC: 0.4288 | Inner AUC: 0.4727
# Macro AUC: 0.5589 | Outer AUC: 0.7476 | Inner AUC: 0.3703
# Macro AUC: 0.4887 | Outer AUC: 0.5509 | Inner AUC: 0.4266
# Macro AUC: 0.4151 | Outer AUC: 0.6473 | Inner AUC: 0.1829
# Macro AUC: 0.5630 | Outer AUC: 0.5908 | Inner AUC: 0.5351
# Macro AUC: 0.6373 | Outer AUC: 0.6211 | Inner AUC: 0.6535
# Macro AUC: 0.6081 | Outer AUC: 0.6969 | Inner AUC: 0.5192
# Macro AUC: 0.7366 | Outer AUC: 0.7325 | Inner AUC: 0.7406
# Macro AUC: 0.6590 | Outer AUC: 0.6361 | Inner AUC: 0.6819

# %%
macro_aucs = [i[0] for i in aucs]
np.mean(macro_aucs), np.std(macro_aucs)
# Out:
# (np.float64(0.5212559482818315), np.float64(0.14057162451219973))
